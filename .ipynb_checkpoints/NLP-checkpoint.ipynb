# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from datetime import datetime, timedelta
from dateutil import relativedelta

# %%
import string

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.text import Text

# %%
df = pd.read_csv("Smoke_House_Google_Reviews.csv")

# %%
df.drop(['query', 'name', 'google_id', 'place_id', 'location_link',
       'reviews_link', 'reviews_per_score', 'reviews','rating','review_id',
       'author_link','author_image','review_img_url',
       'review_link','reviews_id'],axis=1,inplace=True)

# %%
df['text_yn'] = df['review_text'].apply(lambda x: 'no' if x!=x else 'yes')
df['anwser_yn'] = df['owner_answer'].apply(lambda x: 'no' if x!=x else 'yes')
print(df['text_yn'].value_counts())
print(df['anwser_yn'].value_counts())

df[df['text_yn']=='yes']['review_text'].isna().value_counts()

df.head()
# Out:
# yes    1143
# no      579
# Name: text_yn, dtype: int64
# no     1180
# yes     542
# Name: anwser_yn, dtype: int64
#         author_title              author_id  \
# 0     Christian Díaz  118290890328226276251
# 1  Gabriela Santiana  106821844711863729721
# 2         Meir Cohen  104714702665944371857
# 3          kaka kaka  101906364734052474176
# 4   Alberto Martinez  108348994920795296705
#
#                                          review_text owner_answer  \
# 0  (Translated by Google) As always a 10 for this...          NaN
# 1  Delicioso todo.. seguramente repetiremos para ...          NaN
# 2  Great restaurant, great food, good price, slow...          NaN
# 3  Está demasiado bueno la calidad es increíble, ...          NaN
# 4  (Translated by Google) American food restauran...          NaN
#
#    owner_answer_timestamp owner_answer_timestamp_datetime_utc  review_rating  \
# 0                     NaN                                 NaN              5
# 1                     NaN                                 NaN              5
# 2                     NaN                                 NaN              4
# 3                     NaN                                 NaN              5
# 4                     NaN                                 NaN              5
#
#    review_timestamp  review_datetime_utc  review_likes text_yn anwser_yn
# 0        1661161121  08/22/2022 09:38:41             0     yes        no
# 1        1661152489  08/22/2022 07:14:49             1     yes        no
# 2        1661120357  08/21/2022 22:19:17             0     yes        no
# 3        1661114131  08/21/2022 20:35:31             1     yes        no
# 4        1661097601  08/21/2022 16:00:01             1     yes        no

# %%
rev_text = df[df['text_yn']=='yes']
rev_text = rev_text[rev_text['review_rating'] <= 2]
rev_text = pd.DataFrame(rev_text['review_text'])
rev_text.reset_index(inplace=True)

# %%
rev_text.isna().value_counts()
# Out:
# index  review_text
# False  False          109
# dtype: int64

# %%
rev_text.head()
# Out:
#    index                                        review_text
# 0     94  (Translated by Google) Incredible food but the...
# 1    104  (Translated by Google) I've been there twice:\...
# 2    107  Coke with no gas, burned steak, disgusting chi...
# 3    112  (Translated by Google) We were there yesterday...
# 4    227  (Translated by Google) bad service\n\n(Origina...

# %%
rev_text.iloc[0]
# Out:
# index                                                         94
# review_text    (Translated by Google) Incredible food but the...
# Name: 0, dtype: object

# %%
#rev_text['review_text'] = rev_text['review_text'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
#rev_text.head(3)

# %%
#string.punctuation

# %%
#stopwords.words('english')

# %%
'us' in stopwords.words('english')
# Out:
# False

# %%
stopwords.words('english')#.append('us')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
def text_process(review):
    nopunc = [char for char in review if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    nopunc = [word.lower() for word in nopunc.split()]
    return [word for word in nopunc if word.lower() not in stopwords.words('english')]

# %%
rev_text['clean_text'] = rev_text['review_text'].apply(text_process)

# %%
#rev_text['text_split'] = rev_text['review_text'].apply(lambda x: str(x).split())

# %%
rev_text.head()
# Out:
#    index                                        review_text  \
# 0     94  (Translated by Google) Incredible food but the...
# 1    104  (Translated by Google) I've been there twice:\...
# 2    107  Coke with no gas, burned steak, disgusting chi...
# 3    112  (Translated by Google) We were there yesterday...
# 4    227  (Translated by Google) bad service\n\n(Origina...
#
#                                           clean_text
# 0  [translated, google, incredible, food, service...
# 1  [translated, google, ive, twice, first, took, ...
# 2  [coke, gas, burned, steak, disgusting, chips, ...
# 3  [translated, google, yesterday, wednesday, jul...
# 4  [translated, google, bad, service, original, ש...

# %%
g_text = rev_text['clean_text'].iloc[0][:2]
g_text
# Out:
# ['translated', 'google']

# %%
def cleaner(split):
    for string in g_text:
        while string in split:
            split.remove(string)
            
rev_text['clean_text'].apply(cleaner)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 104    None
# 105    None
# 106    None
# 107    None
# 108    None
# Name: clean_text, Length: 109, dtype: object

# %%
#rev_text

# %%
def cleaner2(review):
    while 'original' in review:
        review.index('original')
        del review[review.index('original'):]
            
rev_text['clean_text'].apply(cleaner2)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 104    None
# 105    None
# 106    None
# 107    None
# 108    None
# Name: clean_text, Length: 109, dtype: object

# %%
rev_text.head(3)
# Out:
#    index                                        review_text  \
# 0     94  (Translated by Google) Incredible food but the...
# 1    104  (Translated by Google) I've been there twice:\...
# 2    107  Coke with no gas, burned steak, disgusting chi...
#
#                                           clean_text
# 0  [incredible, food, service, leaves, lot, desir...
# 1  [ive, twice, first, took, wellcooked, santa, f...
# 2  [coke, gas, burned, steak, disgusting, chips, ...

# %%
rev_text
# Out:
#      index                                        review_text  \
# 0       94  (Translated by Google) Incredible food but the...
# 1      104  (Translated by Google) I've been there twice:\...
# 2      107  Coke with no gas, burned steak, disgusting chi...
# 3      112  (Translated by Google) We were there yesterday...
# 4      227  (Translated by Google) bad service\n\n(Origina...
# ..     ...                                                ...
# 104   1689                     Cold pulled pork, and dry ribs
# 105   1690  (Translated by Google) Cold, tasteless a pity....
# 106   1693  They really need to step up their game for it ...
# 107   1706  (Translated by Google) To not come back, as so...
# 108   1708  (Translated by Google) Excellent decoration, e...
#
#                                             clean_text
# 0    [incredible, food, service, leaves, lot, desir...
# 1    [ive, twice, first, took, wellcooked, santa, f...
# 2    [coke, gas, burned, steak, disgusting, chips, ...
# 3    [yesterday, wednesday, july, 20, first, asked,...
# 4                                       [bad, service]
# ..                                                 ...
# 104                    [cold, pulled, pork, dry, ribs]
# 105  [cold, tasteless, pity, place, nice, also, tak...
# 106  [really, need, step, game, work, come, back, q...
# 107  [come, back, soon, arrive, find, wall, large, ...
# 108  [excellent, decoration, excessive, waiting, ti...
#
# [109 rows x 3 columns]

# %%
review_text = rev_text['clean_text'].to_list()

# %%
all_reviews = []

for review in review_text:
    all_reviews = all_reviews + review

all_reviews = pd.Series(all_reviews)

# %%
all_reviews.value_counts().head(10)
# Out:
# food       64
# us         32
# bad        32
# meat       30
# service    26
# like       23
# cold       21
# time       20
# good       20
# place      19
# dtype: int64

# %%
nltk.pos_tag(all_reviews)
# Out:
# [('incredible', 'JJ'),
#  ('food', 'NN'),
#  ('service', 'NN'),
#  ('leaves', 'VBZ'),
#  ('lot', 'RB'),
#  ('desired', 'VBN'),
#  ('130', 'CD'),
#  ('served', 'VBD'),
#  ('food', 'NN'),
#  ('everything', 'NN'),
#  ('ordered', 'VBD'),
#  ('took', 'VBD'),
#  ('forever', 'RB'),
#  ('ive', 'JJ'),
#  ('twice', 'NN'),
#  ('first', 'RB'),
#  ('took', 'VBD'),
#  ('wellcooked', 'VBN'),
#  ('santa', 'JJ'),
#  ('fe', 'NN'),
#  ('arrived', 'VBD'),
#  ('burnt', 'JJ'),
#  ('staff', 'NN'),
#  ('attentive', 'JJ'),
#  ('customer', 'NN'),
#  ('spoke', 'VBD'),
#  ('spanish', 'JJ'),
#  ('factor', 'NN'),
#  ('linguistic', 'JJ'),
#  ('misunderstanding', 'NN'),
#  ('asking', 'VBG'),
#  ('specifically', 'RB'),
#  ('foods', 'NNS'),
#  ('without', 'IN'),
#  ('garlic', 'JJ'),
#  ('difficulty', 'NN'),
#  ('digesting', 'VBG'),
#  ('deaf', 'JJ'),
#  ('ears', 'NNS'),
#  ('full', 'JJ'),
#  ('oil', 'NN'),
#  ('chock', 'NN'),
#  ('full', 'JJ'),
#  ('garlic', 'JJ'),
#  ('second', 'JJ'),
#  ('time', 'NN'),
#  ('went', 'VBD'),
#  ('exactly', 'RB'),
#  ('like', 'IN'),
#  ('first', 'JJ'),
#  ('including', 'VBG'),
#  ('garlic', 'JJ'),
#  ('asking', 'VBG'),
#  ('santa', 'NN'),
#  ('fe', 'NN'),
#  ('medium', 'NN'),
#  ('cooking', 'VBG'),
#  ('obviously', 'RB'),
#  ('arrived', 'VBN'),
#  ('burnt', 'NN'),
#  ('basically', 'RB'),
#  ('would', 'MD'),
#  ('go', 'VB'),
#  ('back', 'RB'),
#  ('staff', 'NN'),
#  ('seem', 'VBP'),
#  ('annoyed', 'VBN'),
#  ('every', 'DT'),
#  ('slightest', 'JJS'),
#  ('request', 'NN'),
#  ('excellent', 'JJ'),
#  ('quality', 'NN'),
#  ('food', 'NN'),
#  ('unable', 'JJ'),
#  ('cook', 'NN'),
#  ('requested', 'VBD'),
#  ('coke', 'NN'),
#  ('gas', 'NN'),
#  ('burned', 'VBD'),
#  ('steak', 'JJ'),
#  ('disgusting', 'VBG'),
#  ('chips', 'NNS'),
#  ('bad', 'JJ'),
#  ('quality', 'NN'),
#  ('meat', 'NN'),
#  ('70', 'CD'),
#  ('fat', 'NN'),
#  ('yesterday', 'NN'),
#  ('wednesday', 'VBP'),
#  ('july', 'RB'),
#  ('20', 'CD'),
#  ('first', 'JJ'),
#  ('asked', 'VBN'),
#  ('foods', 'NNS'),
#  ('people', 'NNS'),
#  ('gluten', 'VBP'),
#  ('intolerance', 'JJ'),
#  ('surprise', 'NN'),
#  ('restaurant', 'NN'),
#  ('name', 'NN'),
#  ('located', 'VBD'),
#  ('street', 'RB'),
#  ('many', 'JJ'),
#  ('visitors', 'NNS'),
#  ('told', 'VBD'),
#  ('nooo', 'JJ'),
#  ('food', 'NN'),
#  ('crosscontaminated', 'VBN'),
#  ('well', 'RB'),
#  ('seemed', 'JJ'),
#  ('people', 'NNS'),
#  ('restaurant', 'VBP'),
#  ('easy', 'JJ'),
#  ('clean', 'JJ'),
#  ('griddle', 'NNS'),
#  ('make', 'VBP'),
#  ('hamburger', 'JJR'),
#  ('thats', 'NNS'),
#  ('little', 'JJ'),
#  ('desire', 'JJ'),
#  ('work', 'NN'),
#  ('people', 'NNS'),
#  ('intolerances', 'NNS'),
#  ('allergies', 'NNS'),
#  ('food', 'NN'),
#  ('complain', 'NN'),
#  ('cannot', 'NN'),
#  ('allowed', 'VBD'),
#  ('need', 'JJ'),
#  ('desire', 'NN'),
#  ('gloves', 'NNS'),
#  ('clean', 'VBP'),
#  ('pan', 'JJ'),
#  ('customer', 'NN'),
#  ('leaves', 'VBZ'),
#  ('happy', 'JJ'),
#  ('complicated', 'VBD'),
#  ('need', 'MD'),
#  ('like', 'VB'),
#  ('job', 'NN'),
#  ('cheers', 'NNS'),
#  ('bad', 'JJ'),
#  ('service', 'NN'),
#  ('disappointing', 'JJ'),
#  ('put', 'VBD'),
#  ('hot', 'JJ'),
#  ('water', 'NN'),
#  ('us', 'PRP'),
#  ('complained', 'VBD'),
#  ('told', 'VBD'),
#  ('us', 'PRP'),
#  ('cold', 'JJ'),
#  ('water', 'NN'),
#  ('loaded', 'VBD'),
#  ('refrigerators', 'NNS'),
#  ('830', 'CD'),
#  ('pm', 'NN'),
#  ('night', 'NN'),
#  ('seems', 'VBZ'),
#  ('bad', 'JJ'),
#  ('management', 'NN'),
#  ('cold', 'JJ'),
#  ('water', 'NN'),
#  ('time', 'NN'),
#  ('fair', 'JJ'),
#  ('attention', 'NN'),
#  ('one', 'CD'),
#  ('hamburgers', 'NNS'),
#  ('completely', 'RB'),
#  ('charred', 'VBN'),
#  ('onion', 'NN'),
#  ('high', 'JJ'),
#  ('price', 'NN'),
#  ('quality', 'NN'),
#  ('attention', 'NN'),
#  ('el', 'VBP'),
#  ('movil', 'JJ'),
#  ('em', 'NN'),
#  ('va', 'NN'),
#  ('portar', 'NN'),
#  ('aqui', 'NN'),
#  ('sol', 'NN'),
#  ('utilitzen', 'JJ'),
#  ('bots', 'NNS'),
#  ('per', 'IN'),
#  ('atraure', 'NN'),
#  ('gent', 'NN'),
#  ('hi', 'NN'),
#  ('anat', 'NN'),
#  ('pero', 'NN'),
#  ('tampoc', 'NN'),
#  ('hi', 'NN'),
#  ('aniré', 'NN'),
#  ('brisket', 'NN'),
#  ('served', 'VBD'),
#  ('week', 'NN'),
#  ('first', 'RB'),
#  ('want', 'VBP'),
#  ('explain', 'JJ'),
#  ('give', 'VB'),
#  ('one', 'CD'),
#  ('star', 'NN'),
#  ('two', 'CD'),
#  ('years', 'NNS'),
#  ('ago', 'RB'),
#  ('went', 'VBD'),
#  ('meat', 'NN'),
#  ('melted', 'VBN'),
#  ('mouth', 'RB'),
#  ('wonderful', 'JJ'),
#  ('quantities', 'NNS'),
#  ('large', 'JJ'),
#  ('ask', 'NNS'),
#  ('take', 'VBP'),
#  ('away', 'RB'),
#  ('exquisite', 'JJ'),
#  ('flavor', 'NN'),
#  ('fresh', 'JJ'),
#  ('two', 'CD'),
#  ('years', 'NNS'),
#  ('ago', 'RB'),
#  ('weeks', 'NNS'),
#  ('went', 'VBD'),
#  ('god', 'JJ'),
#  ('biggest', 'JJS'),
#  ('disappointment', 'NN'),
#  ('tiny', 'JJ'),
#  ('amounts', 'NNS'),
#  ('zero', 'CD'),
#  ('taste', 'NN'),
#  ('worst', 'JJS'),
#  ('soft', 'JJ'),
#  ('drink', 'NN'),
#  ('ive', 'JJ'),
#  ('ever', 'RB'),
#  ('life', 'NN'),
#  ('mixture', 'NN'),
#  ('water', 'NN'),
#  ('sugar', 'NN'),
#  ('turmeric', 'NN'),
#  ('without', 'IN'),
#  ('gas', 'NN'),
#  ('supposedly', 'RB'),
#  ('orange', 'JJ'),
#  ('ones', 'NNS'),
#  ('rash', 'VB'),
#  ('hands', 'NNS'),
#  ('left', 'VBN'),
#  ('want', 'VBP'),
#  ('fair', 'JJ'),
#  ('say', 'VBP'),
#  ('attention', 'NN'),
#  ('bad', 'JJ'),
#  ('made', 'VBN'),
#  ('sad', 'JJ'),
#  ('dont', 'NN'),
#  ('think', 'VBP'),
#  ('come', 'VBN'),
#  ('back', 'RB'),
#  ('would', 'MD'),
#  ('nice', 'VB'),
#  ('went', 'VBD'),
#  ('back', 'RB'),
#  ('beginnings', 'JJ'),
#  ('dont', 'NN'),
#  ('know', 'VBP'),
#  ('change', 'NN'),
#  ('owners', 'NNS'),
#  ('decided', 'VBD'),
#  ('make', 'VBP'),
#  ('cuts', 'NNS'),
#  ('everything', 'NN'),
#  ('could', 'MD'),
#  ('make', 'VB'),
#  ('well', 'RB'),
#  ('done', 'VBN'),
#  ('meat', 'NN'),
#  ('first', 'JJ'),
#  ('time', 'NN'),
#  ('made', 'VBN'),
#  ('wait', 'VBP'),
#  ('1', 'CD'),
#  ('hour', 'NN'),
#  ('food', 'NN'),
#  ('friends', 'NNS'),
#  ('finished', 'VBD'),
#  ('eating', 'VBG'),
#  ('glass', 'NN'),
#  ('pepsi', 'NN'),
#  ('costs', 'VBZ'),
#  ('35€', 'CD'),
#  ('bad', 'JJ'),
#  ('service', 'NN'),
#  ('high', 'JJ'),
#  ('price', 'NN'),
#  ('good', 'JJ'),
#  ('food', 'NN'),
#  ('bad', 'JJ'),
#  ('service', 'NN'),
#  ('wrong', 'JJ'),
#  ('orders', 'NNS'),
#  ('waiter', 'VBP'),
#  ('runs', 'VB'),
#  ('away', 'RP'),
#  ('money', 'NN'),
#  ('forgets', 'NNS'),
#  ('change', 'VBP'),
#  ('shame', 'RB'),
#  ('delicious', 'JJ'),
#  ('food', 'NN'),
#  ('dissapointed', 'VBD'),
#  ('place', 'NN'),
#  ('cold', 'NN'),
#  ('leave', 'VBP'),
#  ('jackets', 'NNS'),
#  ('seated', 'VBD'),
#  ('one', 'CD'),
#  ('table', 'NN'),
#  ('asked', 'VBN'),
#  ('move', 'VBP'),
#  ('stroller', 'NN'),
#  ('saw', 'NN'),
#  ('offered', 'VBD'),
#  ('us', 'PRP'),
#  ('first', 'RB'),
#  ('table', 'JJ'),
#  ('let', 'NN'),
#  ('tell', 'VB'),
#  ('tables', 'NNS'),
#  ('free', 'JJ'),
#  ('bothering', 'VBG'),
#  ('anyone', 'NN'),
#  ('super', 'JJ'),
#  ('weird', 'NN'),
#  ('food', 'NN'),
#  ('ok', 'JJ'),
#  ('bit', 'NN'),
#  ('dry', 'JJ'),
#  ('side', 'NN'),
#  ('far', 'RB'),
#  ('texas', 'JJ'),
#  ('similar', 'JJ'),
#  ('pepsi', 'NN'),
#  ('without', 'IN'),
#  ('bubbles', 'NNS'),
#  ('idea', 'NN'),
#  ('never', 'RB'),
#  ('write', 'RB'),
#  ('bad', 'JJ'),
#  ('reviews', 'NNS'),
#  ('stuck', 'VBD'),
#  ('bad', 'JJ'),
#  ('experience', 'NN'),
#  ('served', 'VBD'),
#  ('us', 'PRP'),
#  ('piece', 'VB'),
#  ('burnt', 'JJ'),
#  ('meat', 'NN'),
#  ('turned', 'VBD'),
#  ('deaf', 'JJ'),
#  ('ear', 'JJ'),
#  ('grievances', 'NNS'),
#  ('unprofessional', 'JJ'),
#  ('staff', 'NN'),
#  ('starting', 'VBG'),
#  ('boss', 'NN'),
#  ('even', 'RB'),
#  ('courage', 'VB'),
#  ('ask', 'RP'),
#  ('everything', 'NN'),
#  ('went', 'VBD'),
#  ('well', 'RB'),
#  ('avoided', 'VBN'),
#  ('carefully', 'RB'),
#  ('ps', 'VB'),
#  ('asked', 'VBD'),
#  ('medium', 'NN'),
#  ('cooking', 'NN'),
#  ('well', 'RB'),
#  ('still', 'RB'),
#  ('waiting', 'VBG'),
#  ('served', 'VBN'),
#  ('wasnt', 'NNS'),
#  ('crowded', 'VBD'),
#  ('slow', 'JJ'),
#  ('service', 'NN'),
#  ('really', 'RB'),
#  ('average', 'JJ'),
#  ('food', 'NN'),
#  ('menu', 'NN'),
#  ('wonderful', 'JJ'),
#  ('dishes', 'NNS'),
#  ('attract', 'VBP'),
#  ('lot', 'NN'),
#  ('attention', 'NN'),
#  ('served', 'VBD'),
#  ('food', 'NN'),
#  ('terrible', 'JJ'),
#  ('food', 'NN'),
#  ('american', 'JJ'),
#  ('flavor', 'NN'),
#  ('anywhere', 'RB'),
#  ('misleading', 'VBG'),
#  ('bbq', 'NN'),
#  ('joint', 'NN'),
#  ('it’s', 'NN'),
#  ('basically', 'RB'),
#  ('steak', 'JJ'),
#  ('house', 'NN'),
#  ('brisket', 'NN'),
#  ('available', 'JJ'),
#  ('days', 'NNS'),
#  ('week', 'NN'),
#  ('maybe', 'RB'),
#  ('weekaccording', 'VBG'),
#  ('waiter', 'RBR'),
#  ('rude', 'VBP'),
#  ('initially', 'RB'),
#  ('salad', 'JJ'),
#  ('came', 'VBD'),
#  ('sautéed', 'JJ'),
#  ('veggies', 'NNS'),
#  ('stir', 'VBP'),
#  ('fried', 'VBN'),
#  ('almost', 'RB'),
#  ('1', 'CD'),
#  ('star', 'NN'),
#  ('give', 'JJ'),
#  ('beef', 'NN'),
#  ('patty', 'RB'),
#  ('burger', 'VBD'),
#  ('ok', 'JJ'),
#  ('misleading', 'NN'),
#  ('edited', 'VBN'),
#  ('review', 'NN'),
#  ('real', 'JJ'),
#  ('truthful', 'JJ'),
#  ('since', 'IN'),
#  ('read', 'NN'),
#  ('owner', 'NN'),
#  ('responded', 'VBD'),
#  ('trying', 'VBG'),
#  ('harsh', 'JJ'),
#  ('bad', 'JJ'),
#  ('behavior', 'JJ'),
#  ('staff', 'NN'),
#  ('specially', 'RB'),
#  ('arabs', 'VBZ'),
#  ('customers', 'NNS'),
#  ('get', 'VBP'),
#  ('bad', 'JJ'),
#  ('racism', 'NN'),
#  ('staffs', 'NNS'),
#  ('arabs', 'VBP'),
#  ('recommend', 'VB'),
#  ('visiting', 'VBG'),
#  ('reason', 'NN'),
#  ('deliberately', 'RB'),
#  ('create', 'VB'),
#  ('problems', 'NNS'),
#  ('arabs', 'JJ'),
#  ('customers', 'NNS'),
#  ('restaurant', 'JJ'),
#  ('workers', 'NNS'),
#  ('making', 'VBG'),
#  ('problems', 'NNS'),
#  ('arab', 'JJ'),
#  ('customers', 'NNS'),
#  ('rude', 'VBP'),
#  ('unfair', 'JJ'),
#  ('treatment', 'NN'),
#  ('recommend', 'NN'),
#  ('visiting', 'VBG'),
#  ('restaurant', 'JJ'),
#  ('hope', 'NN'),
#  ('staff', 'NN'),
#  ('improve', 'VB'),
#  ('behavior', 'NN'),
#  ('drank', 'NN'),
#  ('cook', 'NN'),
#  ('without', 'IN'),
#  ('mask', 'NN'),
#  ('waiters', 'NNS'),
#  ('didnt', 'VBP'),
#  ('rinse', 'NN'),
#  ('dishes', 'NNS'),
#  ('also', 'RB'),
#  ('waited', 'VBD'),
#  ('almost', 'RB'),
#  ('1', 'CD'),
#  ('hour', 'NN'),
#  ('food', 'NN'),
#  ('brought', 'VBD'),
#  ('us', 'PRP'),
#  ('didnt', 'RP'),
#  ('eat', 'NN'),
#  ('badly', 'RB'),
#  ('dont', 'JJ'),
#  ('think', 'VBP'),
#  ('truth', 'NN'),
#  ('comes', 'VBZ'),
#  ('back', 'RB'),
#  ('oh', 'JJ'),
#  ('expensive', 'JJ'),
#  ('place', 'NN'),
#  ('truth', 'NN'),
#  ('lack', 'NN'),
#  ('lot', 'NN'),
#  ('education', 'NN'),
#  ('attend', 'VBP'),
#  ('bad', 'JJ'),
#  ('attention', 'NN'),
#  ('experience', 'NN'),
#  ('fatal', 'JJ'),
#  ('brought', 'VBD'),
#  ('us', 'PRP'),
#  ('dishes', 'VBZ'),
#  ('others', 'NNS'),
#  ('missing', 'VBG'),
#  ('brought', 'VBD'),
#  ('us', 'PRP'),
#  ('extra', 'JJ'),
#  ('drinks', 'NNS'),
#  ('asking', 'VBG'),
#  ('napkins', 'NNS'),
#  ('brought', 'VBD'),
#  ('us', 'PRP'),
#  ('threw', 'VB'),
#  ('away', 'RP'),
#  ('account', 'NN'),
#  ('time', 'NN'),
#  ('paying', 'VBG'),
#  ('ns', 'JJ'),
#  ('overcharging', 'VBG'),
#  ('things', 'NNS'),
#  ('asked', 'VBD'),
#  ('glass', 'JJ'),
#  ('wine', 'NN'),
#  ('wanted', 'VBD'),
#  ('charge', 'NN'),
#  ('us', 'PRP'),
#  ('bottle', 'JJ'),
#  ('attention', 'NN'),
#  ('fatal', 'JJ'),
#  ('part', 'NN'),
#  ('group', 'NN'),
#  ('10', 'CD'),
#  ('people', 'NNS'),
#  ('return', 'VBP'),
#  ('scam', 'RB'),
#  ('much', 'RB'),
#  ('better', 'RBR'),
#  ('foster', 'RB'),
#  ('hollywood', 'JJ'),
#  ('irony', 'NN'),
#  ('cold', 'NN'),
#  ('starters', 'NNS'),
#  ('regular', 'JJ'),
#  ('regular', 'JJ'),
#  ('meat', 'NN'),
#  ('expensive', 'JJ'),
#  ('poor', 'JJ'),
#  ('quality', 'NN'),
#  ('three', 'CD'),
#  ('people', 'NNS'),
#  ('ate', 'VBP'),
#  ('three', 'CD'),
#  ('found', 'VBN'),
#  ('burger', 'RB'),
#  ('meat', 'JJ'),
#  ('compact', 'JJ'),
#  ('dry', 'JJ'),
#  ('didnt', 'NN'),
#  ('look', 'NN'),
#  ('like', 'IN'),
#  ('black', 'JJ'),
#  ('angus', 'NN'),
#  ('ordered', 'VBD'),
#  ('point', 'NN'),
#  ('served', 'VBD'),
#  ('us', 'PRP'),
#  ('well', 'RB'),
#  ('done', 'VBN'),
#  ('quality', 'NN'),
#  ('meat', 'NN'),
#  ('appreciated', 'VBD'),
#  ('waiting', 'VBG'),
#  ('1h', 'CD'),
#  ('see', 'JJ'),
#  ('serve', 'JJ'),
#  ('people', 'NNS'),
#  ('entered', 'VBD'),
#  ('later', 'RB'),
#  ('go', 'VB'),
#  ('without', 'IN'),
#  ('eating', 'VBG'),
#  ('best', 'JJS'),
#  ('tell', 'NN'),
#  ('us', 'PRP'),
#  ('hope', 'VBP'),
#  ('10', 'CD'),
#  ('minutes', 'NNS'),
#  ('final', 'JJ'),
#  ('shot', 'NN'),
#  ('consumptions', 'NNS'),
#  ('charge', 'VBP'),
#  ('us', 'PRP'),
#  ('1h', 'CD'),
#  ('nothing', 'NN'),
#  ('recommendable', 'JJ'),
#  ('ive', 'JJ'),
#  ('going', 'VBG'),
#  ('long', 'JJ'),
#  ('time', 'NN'),
#  ('already', 'RB'),
#  ('twice', 'RB'),
#  ('takes', 'VBZ'),
#  ('hour', 'NN'),
#  ('serve', 'NN'),
#  ('today', 'NN'),
#  ('leave', 'VBP'),
#  ('without', 'IN'),
#  ('eating', 'VBG'),
#  ('food', 'NN'),
#  ('never', 'RB'),
#  ('arrived', 'VBD'),
#  ('wont', 'JJ'),
#  ('back', 'RB'),
#  ('slow', 'JJ'),
#  ('serving', 'NN'),
#  ('hamburgers', 'NNS'),
#  ('excessively', 'RB'),
#  ('expensive', 'JJ'),
#  ('positive', 'JJ'),
#  ('point', 'NN'),
#  ('highlight', 'NN'),
#  ('nachos', 'NNS'),
#  ('unfortunately', 'RB'),
#  ('burger', 'VBP'),
#  ('wasnt', 'JJ'),
#  ('hit', 'NN'),
#  ('meat', 'NN'),
#  ('wasnt', 'NN'),
#  ('juicy', 'NN'),
#  ('worst', 'JJS'),
#  ('food', 'NN'),
#  ('couldnt', 'NN'),
#  ('even', 'RB'),
#  ('eat', 'VBD'),
#  ('anything', 'NN'),
#  ('chips', 'NNS'),
#  ('🤢🤮', 'VBP'),
#  ('get', 'VB'),
#  ('sick', 'JJ'),
#  ('eat', 'NN'),
#  ('dinner', 'NN'),
#  ('🤬', 'VBD'),
#  ('3', 'CD'),
#  ('dry', 'JJ'),
#  ('half', 'NN'),
#  ('ribs', 'JJ'),
#  ('two', 'CD'),
#  ('slices', 'NNS'),
#  ('brisquet', 'VBD'),
#  ('90', 'CD'),
#  ('grams', 'NNS'),
#  ('fat', 'JJ'),
#  ('two', 'CD'),
#  ('portions', 'NNS'),
#  ('potatoes', 'NNS'),
#  ('frozen', 'RB'),
#  ('cane', 'VBP'),
#  ('24', 'CD'),
#  ('euros', 'NNS'),
#  ('left', 'VBD'),
#  ('hungry', 'JJ'),
#  ('tourists', 'NNS'),
#  ('bet', 'VBD'),
#  ('pay', 'NN'),
#  ('positive', 'JJ'),
#  ('recensions', 'NNS'),
#  ('impossible', 'JJ'),
#  ('site', 'NN'),
#  ('4', 'CD'),
#  ('stars', 'NNS'),
#  ('ordered', 'VBN'),
#  ('california', 'RB'),
#  ('burger', 'NN'),
#  ('fries', 'NNS'),
#  ('fries', 'VBZ'),
#  ('dry', 'JJ'),
#  ('even', 'RB'),
#  ('mess', 'NN'),
#  ('burger', 'NN'),
#  ('made', 'VBD'),
#  ('low', 'JJ'),
#  ('quality', 'NN'),
#  ('meat', 'NN'),
#  ('texture', 'NN'),
#  ('taste', 'NN'),
#  ('bbq', 'NN'),
#  ('sauce', 'VBP'),
#  ('super', 'JJR'),
#  ('market', 'NN'),
#  ('quality', 'NN'),
#  ('description', 'NN'),
#  ('restaurant', 'NN'),
#  ('says', 'VBZ'),
#  ('made', 'VBN'),
#  ('soul', 'NN'),
#  ('made', 'VBN'),
#  ('laugh', 'IN'),
#  ('opinion', 'NN'),
#  ('low', 'JJ'),
#  ('quality', 'NN'),
#  ('food', 'NN'),
#  ('tourists', 'NNS'),
#  ('marketing', 'NN'),
#  ('concept', 'NN'),
#  ('interior', 'JJ'),
#  ('design', 'NN'),
#  ('made', 'VBD'),
#  ('professionally', 'RB'),
#  ('pull', 'JJ'),
#  ('pork', 'NN'),
#  ('ribs', 'NN'),
#  ('tomahawks', 'NN'),
#  ('basically', 'RB'),
#  ('main', 'JJ'),
#  ('dishes', 'NNS'),
#  ('restaurant', 'VBP'),
#  ('like', 'IN'),
#  ('needs', 'NNS'),
#  ('supplies', 'NNS'),
#  ('holidays', 'VBP'),
#  ('season', 'NN'),
#  ('disappointed', 'JJ'),
#  ('seeing', 'VBG'),
#  ('advertising', 'NN'),
#  ('instagram', 'RB'),
#  ('good', 'JJ'),
#  ('reviews', 'NNS'),
#  ('around', 'IN'),
#  ('clear', 'JJ'),
#  ('wanted', 'VBD'),
#  ('go', 'VB'),
#  ('try', 'VB'),
#  ('tomahawk', 'NNS'),
#  ('leave', 'VBP'),
#  ('sample', 'JJ'),
#  ('disappointment', 'JJ'),
#  ('whole', 'JJ'),
#  ('center', 'NN'),
#  ('drier', 'NN'),
#  ('eye', 'NN'),
#  ('oneeyed', 'VBD'),
#  ('man', 'NN'),
#  ('took', 'VBD'),
#  ('half', 'DT'),
#  ('hour', 'NN'),
#  ('serve', 'VBP'),
#  ('us', 'PRP'),
#  ('despite', 'IN'),
#  ('fact', 'NN'),
#  ('time', 'NN'),
#  ('hardly', 'RB'),
#  ('people', 'NNS'),
#  ('could', 'MD'),
#  ('enjoy', 'VB'),
#  ('food', 'NN'),
#  ('either', 'CC'),
#  ('two', 'CD'),
#  ('photographers', 'NNS'),
#  ('taking', 'VBG'),
#  ('granted', 'JJ'),
#  ('time', 'NN'),
#  ('made', 'VBD'),
#  ('uncomfortable', 'JJ'),
#  ('second', 'JJ'),
#  ('time', 'NN'),
#  ('wont', 'JJ'),
#  ('third', 'JJ'),
#  ('real', 'JJ'),
#  ('shame', 'NN'),
#  ('like', 'IN'),
#  ('gave', 'VBD'),
#  ('heartburn', 'VBN'),
#  ('day', 'NN'),
#  ('product', 'NN'),
#  ('relieves', 'VBZ'),
#  ('downgrading', 'VBG'),
#  ('review', 'VB'),
#  ('1', 'CD'),
#  ('star', 'NN'),
#  ('due', 'JJ'),
#  ('terrible', 'JJ'),
#  ('response', 'NN'),
#  ('owner', 'NN'),
#  ('based', 'VBN'),
#  ('response', 'NN'),
#  ('theyre', 'NN'),
#  ('basically', 'RB'),
#  ('saying', 'VBG'),
#  ('minutes', 'NNS'),
#  ('late', 'RB'),
#  ('punished', 'VBD'),
#  ('terrible', 'JJ'),
#  ('service', 'NN'),
#  ('table', 'NN'),
#  ('cold', 'NN'),
#  ('along', 'IN'),
#  ('cold', 'JJ'),
#  ('food', 'NN'),
#  ('forget', 'NN'),
#  ('folks', 'NNS'),
#  ('gets', 'VBZ'),
#  ('better', 'JJR'),
#  ('dont', 'NN'),
#  ('love', 'IN'),
#  ('technology', 'NN'),
#  ('please', 'NN'),
#  ('see', 'VB'),
#  ('timeline', 'JJ'),
#  ('image', 'NN'),
#  ('attached', 'VBD'),
#  ('clearly', 'RB'),
#  ('shows', 'VBZ'),
#  ('never', 'RB'),
#  ('anywhere', 'RB'),
#  ('near', 'IN'),
#  ('25', 'CD'),
#  ('minutes', 'NNS'),
#  ('late', 'JJ'),
#  ('minutes', 'NNS'),
#  ('logged', 'VBD'),
#  ('time', 'NN'),
#  ('hey', 'NN'),
#  ('maybe', 'RB'),
#  ('dont', 'JJ'),
#  ('leave', 'VBP'),
#  ('customers', 'NNS'),
#  ('waiting', 'VBG'),
#  ('around', 'IN'),
#  ('someone', 'NN'),
#  ('eventually', 'RB'),
#  ('seat', 'NN'),
#  ('would', 'MD'),
#  ('actually', 'RB'),
#  ('time', 'NN'),
#  ('oh', 'JJ'),
#  ('btw', 'NN'),
#  ('maybe', 'RB'),
#  ('go', 'VBP'),
#  ('speak', 'JJ'),
#  ('waiter', 'NN'),
#  ('ask', 'VB'),
#  ('nice', 'JJ'),
#  ('im', 'NN'),
#  ('100', 'CD'),
#  ('sure', 'JJ'),
#  ('waiter', 'NN'),
#  ('disagree', 'NN'),
#  ('never', 'RB'),
#  ('blamed', 'VBD'),
#  ('bad', 'JJ'),
#  ('experience', 'NN'),
#  ('poor', 'JJ'),
#  ('guy', 'NN'),
#  ('simply', 'RB'),
#  ('overwhelmed', 'VBD'),
#  ('due', 'JJ'),
#  ('bad', 'JJ'),
#  ('management', 'NN'),
#  ('got', 'VBD'),
#  ('tip', 'JJ'),
#  ('us', 'PRP'),
#  ('regardless', 'VBP'),
#  ('clearly', 'RB'),
#  ('enough', 'RB'),
#  ('staff', 'NN'),
#  ('amount', 'NN'),
#  ('people', 'NNS'),
#  ('terrible', 'JJ'),
#  ('quality', 'NN'),
#  ('control', 'NN'),
#  ('serve', 'VBP'),
#  ('cold', 'VBN'),
#  ('food', 'NN'),
#  ('clearly', 'RB'),
#  ('cannot', 'NN'),
#  ('accept', 'IN'),
#  ('criticism', 'NN'),
#  ('either', 'CC'),
#  ('making', 'VBG'),
#  ('stories', 'NNS'),
#  ('25', 'CD'),
#  ('40', 'CD'),
#  ('min', 'NN'),
#  ('depending', 'VBG'),
#  ('wording', 'VBG'),
#  ('minutes', 'NNS'),
#  ('late', 'JJ'),
#  ('cheek', 'NN'),
#  ('imply', 'NN'),
#  ('nice', 'JJ'),
#  ('customers', 'NNS'),
#  ('leaving', 'VBG'),
#  ('honest', 'JJS'),
#  ('feedback', 'NN'),
#  ('oh', 'RB'),
#  ('well', 'RB'),
#  ('sangria', 'JJ'),
#  ('carafe', 'NNS'),
#  ('broke', 'VBD'),
#  ('spilled', 'JJ'),
#  ('apology', 'NN'),
#  ('staff', 'NN'),
#  ('manager', 'NN'),
#  ('blamed', 'VBD'),
#  ('breaking', 'VBG'),
#  ('glass', 'NN'),
#  ('burger', 'NN'),
#  ('absolutely', 'RB'),
#  ('awful', 'JJ'),
#  ('steak', 'NN'),
#  ('gad', 'NN'),
#  ('fat', 'JJ'),
#  ('meat', 'NN'),
#  ('absolutely', 'RB'),
#  ('worse', 'JJ'),
#  ('service', 'NN'),
#  ('i’ve', 'NN'),
#  ('ever', 'RB'),
#  ('server', 'RB'),
#  ('i’ve', 'JJ'),
#  ('never', 'RB'),
#  ('situation', 'NN'),
#  ('like', 'IN'),
#  ('sangria', 'NNS'),
#  ('broke', 'VBD'),
#  ('still', 'RB'),
#  ('charged', 'VBN'),
#  ('us', 'PRP'),
#  ('sangria', 'VBP'),
#  ('absolutely', 'RB'),
#  ('awful', 'JJ'),
#  ('please', 'NN'),
#  ('don’t', 'VB'),
#  ('waste', 'NN'),
#  ('time', 'NN'),
#  ('money', 'NN'),
#  ('food', 'NN'),
#  ('overly', 'RB'),
#  ('simple', 'JJ'),
#  ('overly', 'RB'),
#  ('greasy', 'JJ'),
#  ('rude', 'JJ'),
#  ('staff', 'NN'),
#  ('id', 'NNS'),
#  ('say', 'VBP'),
#  ('stay', 'VB'),
#  ('away', 'RB'),
#  ('go', 'VB'),
#  ('somewhere', 'RB'),
#  ('else', 'RB'),
#  ('dry', 'JJ'),
#  ('hard', 'JJ'),
#  ('chew', 'NN'),
#  ('fries', 'NNS'),
#  ('poor', 'JJ'),
#  ('quality', 'NN'),
#  ('meat', 'NN'),
#  ('burger', 'NN'),
#  ('beer', 'NN'),
#  ('alright', 'VBD'),
#  ('though', 'IN'),
#  ('staff', 'NN'),
#  ('friendly', 'RB'),
#  ('bad', 'JJ'),
#  ('service', 'NN'),
#  ('placed', 'VBD'),
#  ('order', 'NN'),
#  ('one', 'CD'),
#  ('hour', 'NN'),
#  ('ago', 'IN'),
#  ('lost', 'VBN'),
#  ('dont', 'NN'),
#  ('plan', 'NN'),
#  ('provide', 'VBP'),
#  ('either', 'DT'),
#  ('talked', 'VBD'),
#  ('waiters', 'NNS'),
#  ('several', 'JJ'),
#  ('times', 'NNS'),
#  ('never', 'RB'),
#  ('restaurant', 'VBP'),
#  ('penous', 'JJ'),
#  ('service…', 'NN'),
#  ('two', 'CD'),
#  ('times', 'NNS'),
#  ...]

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in all_reviews]
stemmed_words
# Out:
# ['incred',
#  'food',
#  'servic',
#  'leav',
#  'lot',
#  'desir',
#  '130',
#  'serv',
#  'food',
#  'everyth',
#  'order',
#  'took',
#  'forev',
#  'ive',
#  'twice',
#  'first',
#  'took',
#  'wellcook',
#  'santa',
#  'fe',
#  'arriv',
#  'burnt',
#  'staff',
#  'attent',
#  'custom',
#  'spoke',
#  'spanish',
#  'factor',
#  'linguist',
#  'misunderstand',
#  'ask',
#  'specif',
#  'food',
#  'without',
#  'garlic',
#  'difficulti',
#  'digest',
#  'deaf',
#  'ear',
#  'full',
#  'oil',
#  'chock',
#  'full',
#  'garlic',
#  'second',
#  'time',
#  'went',
#  'exactli',
#  'like',
#  'first',
#  'includ',
#  'garlic',
#  'ask',
#  'santa',
#  'fe',
#  'medium',
#  'cook',
#  'obvious',
#  'arriv',
#  'burnt',
#  'basic',
#  'would',
#  'go',
#  'back',
#  'staff',
#  'seem',
#  'annoy',
#  'everi',
#  'slightest',
#  'request',
#  'excel',
#  'qualiti',
#  'food',
#  'unabl',
#  'cook',
#  'request',
#  'coke',
#  'ga',
#  'burn',
#  'steak',
#  'disgust',
#  'chip',
#  'bad',
#  'qualiti',
#  'meat',
#  '70',
#  'fat',
#  'yesterday',
#  'wednesday',
#  'juli',
#  '20',
#  'first',
#  'ask',
#  'food',
#  'peopl',
#  'gluten',
#  'intoler',
#  'surpris',
#  'restaur',
#  'name',
#  'locat',
#  'street',
#  'mani',
#  'visitor',
#  'told',
#  'nooo',
#  'food',
#  'crosscontamin',
#  'well',
#  'seem',
#  'peopl',
#  'restaur',
#  'easi',
#  'clean',
#  'griddl',
#  'make',
#  'hamburg',
#  'that',
#  'littl',
#  'desir',
#  'work',
#  'peopl',
#  'intoler',
#  'allergi',
#  'food',
#  'complain',
#  'cannot',
#  'allow',
#  'need',
#  'desir',
#  'glove',
#  'clean',
#  'pan',
#  'custom',
#  'leav',
#  'happi',
#  'complic',
#  'need',
#  'like',
#  'job',
#  'cheer',
#  'bad',
#  'servic',
#  'disappoint',
#  'put',
#  'hot',
#  'water',
#  'us',
#  'complain',
#  'told',
#  'us',
#  'cold',
#  'water',
#  'load',
#  'refriger',
#  '830',
#  'pm',
#  'night',
#  'seem',
#  'bad',
#  'manag',
#  'cold',
#  'water',
#  'time',
#  'fair',
#  'attent',
#  'one',
#  'hamburg',
#  'complet',
#  'char',
#  'onion',
#  'high',
#  'price',
#  'qualiti',
#  'attent',
#  'el',
#  'movil',
#  'em',
#  'va',
#  'portar',
#  'aqui',
#  'sol',
#  'utilitzen',
#  'bot',
#  'per',
#  'atraur',
#  'gent',
#  'hi',
#  'anat',
#  'pero',
#  'tampoc',
#  'hi',
#  'aniré',
#  'brisket',
#  'serv',
#  'week',
#  'first',
#  'want',
#  'explain',
#  'give',
#  'one',
#  'star',
#  'two',
#  'year',
#  'ago',
#  'went',
#  'meat',
#  'melt',
#  'mouth',
#  'wonder',
#  'quantiti',
#  'larg',
#  'ask',
#  'take',
#  'away',
#  'exquisit',
#  'flavor',
#  'fresh',
#  'two',
#  'year',
#  'ago',
#  'week',
#  'went',
#  'god',
#  'biggest',
#  'disappoint',
#  'tini',
#  'amount',
#  'zero',
#  'tast',
#  'worst',
#  'soft',
#  'drink',
#  'ive',
#  'ever',
#  'life',
#  'mixtur',
#  'water',
#  'sugar',
#  'turmer',
#  'without',
#  'ga',
#  'supposedli',
#  'orang',
#  'one',
#  'rash',
#  'hand',
#  'left',
#  'want',
#  'fair',
#  'say',
#  'attent',
#  'bad',
#  'made',
#  'sad',
#  'dont',
#  'think',
#  'come',
#  'back',
#  'would',
#  'nice',
#  'went',
#  'back',
#  'begin',
#  'dont',
#  'know',
#  'chang',
#  'owner',
#  'decid',
#  'make',
#  'cut',
#  'everyth',
#  'could',
#  'make',
#  'well',
#  'done',
#  'meat',
#  'first',
#  'time',
#  'made',
#  'wait',
#  '1',
#  'hour',
#  'food',
#  'friend',
#  'finish',
#  'eat',
#  'glass',
#  'pepsi',
#  'cost',
#  '35€',
#  'bad',
#  'servic',
#  'high',
#  'price',
#  'good',
#  'food',
#  'bad',
#  'servic',
#  'wrong',
#  'order',
#  'waiter',
#  'run',
#  'away',
#  'money',
#  'forget',
#  'chang',
#  'shame',
#  'delici',
#  'food',
#  'dissapoint',
#  'place',
#  'cold',
#  'leav',
#  'jacket',
#  'seat',
#  'one',
#  'tabl',
#  'ask',
#  'move',
#  'stroller',
#  'saw',
#  'offer',
#  'us',
#  'first',
#  'tabl',
#  'let',
#  'tell',
#  'tabl',
#  'free',
#  'bother',
#  'anyon',
#  'super',
#  'weird',
#  'food',
#  'ok',
#  'bit',
#  'dri',
#  'side',
#  'far',
#  'texa',
#  'similar',
#  'pepsi',
#  'without',
#  'bubbl',
#  'idea',
#  'never',
#  'write',
#  'bad',
#  'review',
#  'stuck',
#  'bad',
#  'experi',
#  'serv',
#  'us',
#  'piec',
#  'burnt',
#  'meat',
#  'turn',
#  'deaf',
#  'ear',
#  'grievanc',
#  'unprofession',
#  'staff',
#  'start',
#  'boss',
#  'even',
#  'courag',
#  'ask',
#  'everyth',
#  'went',
#  'well',
#  'avoid',
#  'care',
#  'ps',
#  'ask',
#  'medium',
#  'cook',
#  'well',
#  'still',
#  'wait',
#  'serv',
#  'wasnt',
#  'crowd',
#  'slow',
#  'servic',
#  'realli',
#  'averag',
#  'food',
#  'menu',
#  'wonder',
#  'dish',
#  'attract',
#  'lot',
#  'attent',
#  'serv',
#  'food',
#  'terribl',
#  'food',
#  'american',
#  'flavor',
#  'anywher',
#  'mislead',
#  'bbq',
#  'joint',
#  'it’',
#  'basic',
#  'steak',
#  'hous',
#  'brisket',
#  'avail',
#  'day',
#  'week',
#  'mayb',
#  'weekaccord',
#  'waiter',
#  'rude',
#  'initi',
#  'salad',
#  'came',
#  'sauté',
#  'veggi',
#  'stir',
#  'fri',
#  'almost',
#  '1',
#  'star',
#  'give',
#  'beef',
#  'patti',
#  'burger',
#  'ok',
#  'mislead',
#  'edit',
#  'review',
#  'real',
#  'truth',
#  'sinc',
#  'read',
#  'owner',
#  'respond',
#  'tri',
#  'harsh',
#  'bad',
#  'behavior',
#  'staff',
#  'special',
#  'arab',
#  'custom',
#  'get',
#  'bad',
#  'racism',
#  'staff',
#  'arab',
#  'recommend',
#  'visit',
#  'reason',
#  'deliber',
#  'creat',
#  'problem',
#  'arab',
#  'custom',
#  'restaur',
#  'worker',
#  'make',
#  'problem',
#  'arab',
#  'custom',
#  'rude',
#  'unfair',
#  'treatment',
#  'recommend',
#  'visit',
#  'restaur',
#  'hope',
#  'staff',
#  'improv',
#  'behavior',
#  'drank',
#  'cook',
#  'without',
#  'mask',
#  'waiter',
#  'didnt',
#  'rins',
#  'dish',
#  'also',
#  'wait',
#  'almost',
#  '1',
#  'hour',
#  'food',
#  'brought',
#  'us',
#  'didnt',
#  'eat',
#  'badli',
#  'dont',
#  'think',
#  'truth',
#  'come',
#  'back',
#  'oh',
#  'expens',
#  'place',
#  'truth',
#  'lack',
#  'lot',
#  'educ',
#  'attend',
#  'bad',
#  'attent',
#  'experi',
#  'fatal',
#  'brought',
#  'us',
#  'dish',
#  'other',
#  'miss',
#  'brought',
#  'us',
#  'extra',
#  'drink',
#  'ask',
#  'napkin',
#  'brought',
#  'us',
#  'threw',
#  'away',
#  'account',
#  'time',
#  'pay',
#  'ns',
#  'overcharg',
#  'thing',
#  'ask',
#  'glass',
#  'wine',
#  'want',
#  'charg',
#  'us',
#  'bottl',
#  'attent',
#  'fatal',
#  'part',
#  'group',
#  '10',
#  'peopl',
#  'return',
#  'scam',
#  'much',
#  'better',
#  'foster',
#  'hollywood',
#  'ironi',
#  'cold',
#  'starter',
#  'regular',
#  'regular',
#  'meat',
#  'expens',
#  'poor',
#  'qualiti',
#  'three',
#  'peopl',
#  'ate',
#  'three',
#  'found',
#  'burger',
#  'meat',
#  'compact',
#  'dri',
#  'didnt',
#  'look',
#  'like',
#  'black',
#  'angu',
#  'order',
#  'point',
#  'serv',
#  'us',
#  'well',
#  'done',
#  'qualiti',
#  'meat',
#  'appreci',
#  'wait',
#  '1h',
#  'see',
#  'serv',
#  'peopl',
#  'enter',
#  'later',
#  'go',
#  'without',
#  'eat',
#  'best',
#  'tell',
#  'us',
#  'hope',
#  '10',
#  'minut',
#  'final',
#  'shot',
#  'consumpt',
#  'charg',
#  'us',
#  '1h',
#  'noth',
#  'recommend',
#  'ive',
#  'go',
#  'long',
#  'time',
#  'alreadi',
#  'twice',
#  'take',
#  'hour',
#  'serv',
#  'today',
#  'leav',
#  'without',
#  'eat',
#  'food',
#  'never',
#  'arriv',
#  'wont',
#  'back',
#  'slow',
#  'serv',
#  'hamburg',
#  'excess',
#  'expens',
#  'posit',
#  'point',
#  'highlight',
#  'nacho',
#  'unfortun',
#  'burger',
#  'wasnt',
#  'hit',
#  'meat',
#  'wasnt',
#  'juici',
#  'worst',
#  'food',
#  'couldnt',
#  'even',
#  'eat',
#  'anyth',
#  'chip',
#  '🤢🤮',
#  'get',
#  'sick',
#  'eat',
#  'dinner',
#  '🤬',
#  '3',
#  'dri',
#  'half',
#  'rib',
#  'two',
#  'slice',
#  'brisquet',
#  '90',
#  'gram',
#  'fat',
#  'two',
#  'portion',
#  'potato',
#  'frozen',
#  'cane',
#  '24',
#  'euro',
#  'left',
#  'hungri',
#  'tourist',
#  'bet',
#  'pay',
#  'posit',
#  'recens',
#  'imposs',
#  'site',
#  '4',
#  'star',
#  'order',
#  'california',
#  'burger',
#  'fri',
#  'fri',
#  'dri',
#  'even',
#  'mess',
#  'burger',
#  'made',
#  'low',
#  'qualiti',
#  'meat',
#  'textur',
#  'tast',
#  'bbq',
#  'sauc',
#  'super',
#  'market',
#  'qualiti',
#  'descript',
#  'restaur',
#  'say',
#  'made',
#  'soul',
#  'made',
#  'laugh',
#  'opinion',
#  'low',
#  'qualiti',
#  'food',
#  'tourist',
#  'market',
#  'concept',
#  'interior',
#  'design',
#  'made',
#  'profession',
#  'pull',
#  'pork',
#  'rib',
#  'tomahawk',
#  'basic',
#  'main',
#  'dish',
#  'restaur',
#  'like',
#  'need',
#  'suppli',
#  'holiday',
#  'season',
#  'disappoint',
#  'see',
#  'advertis',
#  'instagram',
#  'good',
#  'review',
#  'around',
#  'clear',
#  'want',
#  'go',
#  'tri',
#  'tomahawk',
#  'leav',
#  'sampl',
#  'disappoint',
#  'whole',
#  'center',
#  'drier',
#  'eye',
#  'oneey',
#  'man',
#  'took',
#  'half',
#  'hour',
#  'serv',
#  'us',
#  'despit',
#  'fact',
#  'time',
#  'hardli',
#  'peopl',
#  'could',
#  'enjoy',
#  'food',
#  'either',
#  'two',
#  'photograph',
#  'take',
#  'grant',
#  'time',
#  'made',
#  'uncomfort',
#  'second',
#  'time',
#  'wont',
#  'third',
#  'real',
#  'shame',
#  'like',
#  'gave',
#  'heartburn',
#  'day',
#  'product',
#  'reliev',
#  'downgrad',
#  'review',
#  '1',
#  'star',
#  'due',
#  'terribl',
#  'respons',
#  'owner',
#  'base',
#  'respons',
#  'theyr',
#  'basic',
#  'say',
#  'minut',
#  'late',
#  'punish',
#  'terribl',
#  'servic',
#  'tabl',
#  'cold',
#  'along',
#  'cold',
#  'food',
#  'forget',
#  'folk',
#  'get',
#  'better',
#  'dont',
#  'love',
#  'technolog',
#  'pleas',
#  'see',
#  'timelin',
#  'imag',
#  'attach',
#  'clearli',
#  'show',
#  'never',
#  'anywher',
#  'near',
#  '25',
#  'minut',
#  'late',
#  'minut',
#  'log',
#  'time',
#  'hey',
#  'mayb',
#  'dont',
#  'leav',
#  'custom',
#  'wait',
#  'around',
#  'someon',
#  'eventu',
#  'seat',
#  'would',
#  'actual',
#  'time',
#  'oh',
#  'btw',
#  'mayb',
#  'go',
#  'speak',
#  'waiter',
#  'ask',
#  'nice',
#  'im',
#  '100',
#  'sure',
#  'waiter',
#  'disagre',
#  'never',
#  'blame',
#  'bad',
#  'experi',
#  'poor',
#  'guy',
#  'simpli',
#  'overwhelm',
#  'due',
#  'bad',
#  'manag',
#  'got',
#  'tip',
#  'us',
#  'regardless',
#  'clearli',
#  'enough',
#  'staff',
#  'amount',
#  'peopl',
#  'terribl',
#  'qualiti',
#  'control',
#  'serv',
#  'cold',
#  'food',
#  'clearli',
#  'cannot',
#  'accept',
#  'critic',
#  'either',
#  'make',
#  'stori',
#  '25',
#  '40',
#  'min',
#  'depend',
#  'word',
#  'minut',
#  'late',
#  'cheek',
#  'impli',
#  'nice',
#  'custom',
#  'leav',
#  'honest',
#  'feedback',
#  'oh',
#  'well',
#  'sangria',
#  'caraf',
#  'broke',
#  'spill',
#  'apolog',
#  'staff',
#  'manag',
#  'blame',
#  'break',
#  'glass',
#  'burger',
#  'absolut',
#  'aw',
#  'steak',
#  'gad',
#  'fat',
#  'meat',
#  'absolut',
#  'wors',
#  'servic',
#  'i’v',
#  'ever',
#  'server',
#  'i’v',
#  'never',
#  'situat',
#  'like',
#  'sangria',
#  'broke',
#  'still',
#  'charg',
#  'us',
#  'sangria',
#  'absolut',
#  'aw',
#  'pleas',
#  'don’t',
#  'wast',
#  'time',
#  'money',
#  'food',
#  'overli',
#  'simpl',
#  'overli',
#  'greasi',
#  'rude',
#  'staff',
#  'id',
#  'say',
#  'stay',
#  'away',
#  'go',
#  'somewher',
#  'els',
#  'dri',
#  'hard',
#  'chew',
#  'fri',
#  'poor',
#  'qualiti',
#  'meat',
#  'burger',
#  'beer',
#  'alright',
#  'though',
#  'staff',
#  'friendli',
#  'bad',
#  'servic',
#  'place',
#  'order',
#  'one',
#  'hour',
#  'ago',
#  'lost',
#  'dont',
#  'plan',
#  'provid',
#  'either',
#  'talk',
#  'waiter',
#  'sever',
#  'time',
#  'never',
#  'restaur',
#  'penou',
#  'service…',
#  'two',
#  'time',
#  ...]

# %%
pd.Series(stemmed_words).value_counts().head(10)
# Out:
# food      66
# us        32
# bad       32
# meat      31
# servic    26
# time      25
# serv      23
# like      23
# place     22
# order     22
# dtype: int64

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in all_reviews]
lemmatized_words
# Out:
# ['incredible',
#  'food',
#  'service',
#  'leaf',
#  'lot',
#  'desired',
#  '130',
#  'served',
#  'food',
#  'everything',
#  'ordered',
#  'took',
#  'forever',
#  'ive',
#  'twice',
#  'first',
#  'took',
#  'wellcooked',
#  'santa',
#  'fe',
#  'arrived',
#  'burnt',
#  'staff',
#  'attentive',
#  'customer',
#  'spoke',
#  'spanish',
#  'factor',
#  'linguistic',
#  'misunderstanding',
#  'asking',
#  'specifically',
#  'food',
#  'without',
#  'garlic',
#  'difficulty',
#  'digesting',
#  'deaf',
#  'ear',
#  'full',
#  'oil',
#  'chock',
#  'full',
#  'garlic',
#  'second',
#  'time',
#  'went',
#  'exactly',
#  'like',
#  'first',
#  'including',
#  'garlic',
#  'asking',
#  'santa',
#  'fe',
#  'medium',
#  'cooking',
#  'obviously',
#  'arrived',
#  'burnt',
#  'basically',
#  'would',
#  'go',
#  'back',
#  'staff',
#  'seem',
#  'annoyed',
#  'every',
#  'slightest',
#  'request',
#  'excellent',
#  'quality',
#  'food',
#  'unable',
#  'cook',
#  'requested',
#  'coke',
#  'gas',
#  'burned',
#  'steak',
#  'disgusting',
#  'chip',
#  'bad',
#  'quality',
#  'meat',
#  '70',
#  'fat',
#  'yesterday',
#  'wednesday',
#  'july',
#  '20',
#  'first',
#  'asked',
#  'food',
#  'people',
#  'gluten',
#  'intolerance',
#  'surprise',
#  'restaurant',
#  'name',
#  'located',
#  'street',
#  'many',
#  'visitor',
#  'told',
#  'nooo',
#  'food',
#  'crosscontaminated',
#  'well',
#  'seemed',
#  'people',
#  'restaurant',
#  'easy',
#  'clean',
#  'griddle',
#  'make',
#  'hamburger',
#  'thats',
#  'little',
#  'desire',
#  'work',
#  'people',
#  'intolerance',
#  'allergy',
#  'food',
#  'complain',
#  'cannot',
#  'allowed',
#  'need',
#  'desire',
#  'glove',
#  'clean',
#  'pan',
#  'customer',
#  'leaf',
#  'happy',
#  'complicated',
#  'need',
#  'like',
#  'job',
#  'cheer',
#  'bad',
#  'service',
#  'disappointing',
#  'put',
#  'hot',
#  'water',
#  'u',
#  'complained',
#  'told',
#  'u',
#  'cold',
#  'water',
#  'loaded',
#  'refrigerator',
#  '830',
#  'pm',
#  'night',
#  'seems',
#  'bad',
#  'management',
#  'cold',
#  'water',
#  'time',
#  'fair',
#  'attention',
#  'one',
#  'hamburger',
#  'completely',
#  'charred',
#  'onion',
#  'high',
#  'price',
#  'quality',
#  'attention',
#  'el',
#  'movil',
#  'em',
#  'va',
#  'portar',
#  'aqui',
#  'sol',
#  'utilitzen',
#  'bot',
#  'per',
#  'atraure',
#  'gent',
#  'hi',
#  'anat',
#  'pero',
#  'tampoc',
#  'hi',
#  'aniré',
#  'brisket',
#  'served',
#  'week',
#  'first',
#  'want',
#  'explain',
#  'give',
#  'one',
#  'star',
#  'two',
#  'year',
#  'ago',
#  'went',
#  'meat',
#  'melted',
#  'mouth',
#  'wonderful',
#  'quantity',
#  'large',
#  'ask',
#  'take',
#  'away',
#  'exquisite',
#  'flavor',
#  'fresh',
#  'two',
#  'year',
#  'ago',
#  'week',
#  'went',
#  'god',
#  'biggest',
#  'disappointment',
#  'tiny',
#  'amount',
#  'zero',
#  'taste',
#  'worst',
#  'soft',
#  'drink',
#  'ive',
#  'ever',
#  'life',
#  'mixture',
#  'water',
#  'sugar',
#  'turmeric',
#  'without',
#  'gas',
#  'supposedly',
#  'orange',
#  'one',
#  'rash',
#  'hand',
#  'left',
#  'want',
#  'fair',
#  'say',
#  'attention',
#  'bad',
#  'made',
#  'sad',
#  'dont',
#  'think',
#  'come',
#  'back',
#  'would',
#  'nice',
#  'went',
#  'back',
#  'beginning',
#  'dont',
#  'know',
#  'change',
#  'owner',
#  'decided',
#  'make',
#  'cut',
#  'everything',
#  'could',
#  'make',
#  'well',
#  'done',
#  'meat',
#  'first',
#  'time',
#  'made',
#  'wait',
#  '1',
#  'hour',
#  'food',
#  'friend',
#  'finished',
#  'eating',
#  'glass',
#  'pepsi',
#  'cost',
#  '35€',
#  'bad',
#  'service',
#  'high',
#  'price',
#  'good',
#  'food',
#  'bad',
#  'service',
#  'wrong',
#  'order',
#  'waiter',
#  'run',
#  'away',
#  'money',
#  'forgets',
#  'change',
#  'shame',
#  'delicious',
#  'food',
#  'dissapointed',
#  'place',
#  'cold',
#  'leave',
#  'jacket',
#  'seated',
#  'one',
#  'table',
#  'asked',
#  'move',
#  'stroller',
#  'saw',
#  'offered',
#  'u',
#  'first',
#  'table',
#  'let',
#  'tell',
#  'table',
#  'free',
#  'bothering',
#  'anyone',
#  'super',
#  'weird',
#  'food',
#  'ok',
#  'bit',
#  'dry',
#  'side',
#  'far',
#  'texas',
#  'similar',
#  'pepsi',
#  'without',
#  'bubble',
#  'idea',
#  'never',
#  'write',
#  'bad',
#  'review',
#  'stuck',
#  'bad',
#  'experience',
#  'served',
#  'u',
#  'piece',
#  'burnt',
#  'meat',
#  'turned',
#  'deaf',
#  'ear',
#  'grievance',
#  'unprofessional',
#  'staff',
#  'starting',
#  'bos',
#  'even',
#  'courage',
#  'ask',
#  'everything',
#  'went',
#  'well',
#  'avoided',
#  'carefully',
#  'p',
#  'asked',
#  'medium',
#  'cooking',
#  'well',
#  'still',
#  'waiting',
#  'served',
#  'wasnt',
#  'crowded',
#  'slow',
#  'service',
#  'really',
#  'average',
#  'food',
#  'menu',
#  'wonderful',
#  'dish',
#  'attract',
#  'lot',
#  'attention',
#  'served',
#  'food',
#  'terrible',
#  'food',
#  'american',
#  'flavor',
#  'anywhere',
#  'misleading',
#  'bbq',
#  'joint',
#  'it’s',
#  'basically',
#  'steak',
#  'house',
#  'brisket',
#  'available',
#  'day',
#  'week',
#  'maybe',
#  'weekaccording',
#  'waiter',
#  'rude',
#  'initially',
#  'salad',
#  'came',
#  'sautéed',
#  'veggie',
#  'stir',
#  'fried',
#  'almost',
#  '1',
#  'star',
#  'give',
#  'beef',
#  'patty',
#  'burger',
#  'ok',
#  'misleading',
#  'edited',
#  'review',
#  'real',
#  'truthful',
#  'since',
#  'read',
#  'owner',
#  'responded',
#  'trying',
#  'harsh',
#  'bad',
#  'behavior',
#  'staff',
#  'specially',
#  'arab',
#  'customer',
#  'get',
#  'bad',
#  'racism',
#  'staff',
#  'arab',
#  'recommend',
#  'visiting',
#  'reason',
#  'deliberately',
#  'create',
#  'problem',
#  'arab',
#  'customer',
#  'restaurant',
#  'worker',
#  'making',
#  'problem',
#  'arab',
#  'customer',
#  'rude',
#  'unfair',
#  'treatment',
#  'recommend',
#  'visiting',
#  'restaurant',
#  'hope',
#  'staff',
#  'improve',
#  'behavior',
#  'drank',
#  'cook',
#  'without',
#  'mask',
#  'waiter',
#  'didnt',
#  'rinse',
#  'dish',
#  'also',
#  'waited',
#  'almost',
#  '1',
#  'hour',
#  'food',
#  'brought',
#  'u',
#  'didnt',
#  'eat',
#  'badly',
#  'dont',
#  'think',
#  'truth',
#  'come',
#  'back',
#  'oh',
#  'expensive',
#  'place',
#  'truth',
#  'lack',
#  'lot',
#  'education',
#  'attend',
#  'bad',
#  'attention',
#  'experience',
#  'fatal',
#  'brought',
#  'u',
#  'dish',
#  'others',
#  'missing',
#  'brought',
#  'u',
#  'extra',
#  'drink',
#  'asking',
#  'napkin',
#  'brought',
#  'u',
#  'threw',
#  'away',
#  'account',
#  'time',
#  'paying',
#  'n',
#  'overcharging',
#  'thing',
#  'asked',
#  'glass',
#  'wine',
#  'wanted',
#  'charge',
#  'u',
#  'bottle',
#  'attention',
#  'fatal',
#  'part',
#  'group',
#  '10',
#  'people',
#  'return',
#  'scam',
#  'much',
#  'better',
#  'foster',
#  'hollywood',
#  'irony',
#  'cold',
#  'starter',
#  'regular',
#  'regular',
#  'meat',
#  'expensive',
#  'poor',
#  'quality',
#  'three',
#  'people',
#  'ate',
#  'three',
#  'found',
#  'burger',
#  'meat',
#  'compact',
#  'dry',
#  'didnt',
#  'look',
#  'like',
#  'black',
#  'angus',
#  'ordered',
#  'point',
#  'served',
#  'u',
#  'well',
#  'done',
#  'quality',
#  'meat',
#  'appreciated',
#  'waiting',
#  '1h',
#  'see',
#  'serve',
#  'people',
#  'entered',
#  'later',
#  'go',
#  'without',
#  'eating',
#  'best',
#  'tell',
#  'u',
#  'hope',
#  '10',
#  'minute',
#  'final',
#  'shot',
#  'consumption',
#  'charge',
#  'u',
#  '1h',
#  'nothing',
#  'recommendable',
#  'ive',
#  'going',
#  'long',
#  'time',
#  'already',
#  'twice',
#  'take',
#  'hour',
#  'serve',
#  'today',
#  'leave',
#  'without',
#  'eating',
#  'food',
#  'never',
#  'arrived',
#  'wont',
#  'back',
#  'slow',
#  'serving',
#  'hamburger',
#  'excessively',
#  'expensive',
#  'positive',
#  'point',
#  'highlight',
#  'nacho',
#  'unfortunately',
#  'burger',
#  'wasnt',
#  'hit',
#  'meat',
#  'wasnt',
#  'juicy',
#  'worst',
#  'food',
#  'couldnt',
#  'even',
#  'eat',
#  'anything',
#  'chip',
#  '🤢🤮',
#  'get',
#  'sick',
#  'eat',
#  'dinner',
#  '🤬',
#  '3',
#  'dry',
#  'half',
#  'rib',
#  'two',
#  'slice',
#  'brisquet',
#  '90',
#  'gram',
#  'fat',
#  'two',
#  'portion',
#  'potato',
#  'frozen',
#  'cane',
#  '24',
#  'euro',
#  'left',
#  'hungry',
#  'tourist',
#  'bet',
#  'pay',
#  'positive',
#  'recensions',
#  'impossible',
#  'site',
#  '4',
#  'star',
#  'ordered',
#  'california',
#  'burger',
#  'fry',
#  'fry',
#  'dry',
#  'even',
#  'mess',
#  'burger',
#  'made',
#  'low',
#  'quality',
#  'meat',
#  'texture',
#  'taste',
#  'bbq',
#  'sauce',
#  'super',
#  'market',
#  'quality',
#  'description',
#  'restaurant',
#  'say',
#  'made',
#  'soul',
#  'made',
#  'laugh',
#  'opinion',
#  'low',
#  'quality',
#  'food',
#  'tourist',
#  'marketing',
#  'concept',
#  'interior',
#  'design',
#  'made',
#  'professionally',
#  'pull',
#  'pork',
#  'rib',
#  'tomahawk',
#  'basically',
#  'main',
#  'dish',
#  'restaurant',
#  'like',
#  'need',
#  'supply',
#  'holiday',
#  'season',
#  'disappointed',
#  'seeing',
#  'advertising',
#  'instagram',
#  'good',
#  'review',
#  'around',
#  'clear',
#  'wanted',
#  'go',
#  'try',
#  'tomahawk',
#  'leave',
#  'sample',
#  'disappointment',
#  'whole',
#  'center',
#  'drier',
#  'eye',
#  'oneeyed',
#  'man',
#  'took',
#  'half',
#  'hour',
#  'serve',
#  'u',
#  'despite',
#  'fact',
#  'time',
#  'hardly',
#  'people',
#  'could',
#  'enjoy',
#  'food',
#  'either',
#  'two',
#  'photographer',
#  'taking',
#  'granted',
#  'time',
#  'made',
#  'uncomfortable',
#  'second',
#  'time',
#  'wont',
#  'third',
#  'real',
#  'shame',
#  'like',
#  'gave',
#  'heartburn',
#  'day',
#  'product',
#  'relief',
#  'downgrading',
#  'review',
#  '1',
#  'star',
#  'due',
#  'terrible',
#  'response',
#  'owner',
#  'based',
#  'response',
#  'theyre',
#  'basically',
#  'saying',
#  'minute',
#  'late',
#  'punished',
#  'terrible',
#  'service',
#  'table',
#  'cold',
#  'along',
#  'cold',
#  'food',
#  'forget',
#  'folk',
#  'get',
#  'better',
#  'dont',
#  'love',
#  'technology',
#  'please',
#  'see',
#  'timeline',
#  'image',
#  'attached',
#  'clearly',
#  'show',
#  'never',
#  'anywhere',
#  'near',
#  '25',
#  'minute',
#  'late',
#  'minute',
#  'logged',
#  'time',
#  'hey',
#  'maybe',
#  'dont',
#  'leave',
#  'customer',
#  'waiting',
#  'around',
#  'someone',
#  'eventually',
#  'seat',
#  'would',
#  'actually',
#  'time',
#  'oh',
#  'btw',
#  'maybe',
#  'go',
#  'speak',
#  'waiter',
#  'ask',
#  'nice',
#  'im',
#  '100',
#  'sure',
#  'waiter',
#  'disagree',
#  'never',
#  'blamed',
#  'bad',
#  'experience',
#  'poor',
#  'guy',
#  'simply',
#  'overwhelmed',
#  'due',
#  'bad',
#  'management',
#  'got',
#  'tip',
#  'u',
#  'regardless',
#  'clearly',
#  'enough',
#  'staff',
#  'amount',
#  'people',
#  'terrible',
#  'quality',
#  'control',
#  'serve',
#  'cold',
#  'food',
#  'clearly',
#  'cannot',
#  'accept',
#  'criticism',
#  'either',
#  'making',
#  'story',
#  '25',
#  '40',
#  'min',
#  'depending',
#  'wording',
#  'minute',
#  'late',
#  'cheek',
#  'imply',
#  'nice',
#  'customer',
#  'leaving',
#  'honest',
#  'feedback',
#  'oh',
#  'well',
#  'sangria',
#  'carafe',
#  'broke',
#  'spilled',
#  'apology',
#  'staff',
#  'manager',
#  'blamed',
#  'breaking',
#  'glass',
#  'burger',
#  'absolutely',
#  'awful',
#  'steak',
#  'gad',
#  'fat',
#  'meat',
#  'absolutely',
#  'worse',
#  'service',
#  'i’ve',
#  'ever',
#  'server',
#  'i’ve',
#  'never',
#  'situation',
#  'like',
#  'sangria',
#  'broke',
#  'still',
#  'charged',
#  'u',
#  'sangria',
#  'absolutely',
#  'awful',
#  'please',
#  'don’t',
#  'waste',
#  'time',
#  'money',
#  'food',
#  'overly',
#  'simple',
#  'overly',
#  'greasy',
#  'rude',
#  'staff',
#  'id',
#  'say',
#  'stay',
#  'away',
#  'go',
#  'somewhere',
#  'else',
#  'dry',
#  'hard',
#  'chew',
#  'fry',
#  'poor',
#  'quality',
#  'meat',
#  'burger',
#  'beer',
#  'alright',
#  'though',
#  'staff',
#  'friendly',
#  'bad',
#  'service',
#  'placed',
#  'order',
#  'one',
#  'hour',
#  'ago',
#  'lost',
#  'dont',
#  'plan',
#  'provide',
#  'either',
#  'talked',
#  'waiter',
#  'several',
#  'time',
#  'never',
#  'restaurant',
#  'penous',
#  'service…',
#  'two',
#  'time',
#  ...]

# %%
pd.Series(lemmatized_words).value_counts().head(10)
# Out:
# food          66
# u             32
# bad           32
# meat          31
# service       26
# time          25
# like          23
# cold          21
# place         21
# restaurant    20
# dtype: int64

# %%
rev_text['clean_text_merged'] = rev_text['clean_text'].apply(lambda x: ' '.join(x))

# %%
Text(lemmatized_words).concordance('bad')
# Out:
# Displaying 25 of 32 matches:
# coke gas burned steak disgusting chip bad quality meat 70 fat yesterday wednesd
# happy complicated need like job cheer bad service disappointing put hot water u
# oaded refrigerator 830 pm night seems bad management cold water time fair atten
# ash hand left want fair say attention bad made sad dont think come back would n
#  finished eating glass pepsi cost 35€ bad service high price good food bad serv
#  35€ bad service high price good food bad service wrong order waiter run away m
# pepsi without bubble idea never write bad review stuck bad experience served u
# ble idea never write bad review stuck bad experience served u piece burnt meat
# nce read owner responded trying harsh bad behavior staff specially arab custome
# ior staff specially arab customer get bad racism staff arab recommend visiting
# place truth lack lot education attend bad attention experience fatal brought u
# 100 sure waiter disagree never blamed bad experience poor guy simply overwhelme
# ience poor guy simply overwhelmed due bad management got tip u regardless clear
# er beer alright though staff friendly bad service placed order one hour ago los
# n little seriousness respect language bad it’s place lost “guides” bad service
# language bad it’s place lost “guides” bad service brought u food hour half late
# t finally food arrived one eaten food bad side bad experience im going back cra
#  food arrived one eaten food bad side bad experience im going back crazy went h
#  good rib onion ring burned hamburger bad potato would return robbery color tas
# ked like colored paste onion ring fry bad general nothing flavor without excess
# auce little seasoning food meat juicy bad food bad service never tread went yes
# le seasoning food meat juicy bad food bad service never tread went yesterday co
# tination expensive food service maybe bad day 16 people wrong middle bad way pa
#  maybe bad day 16 people wrong middle bad way part bos waiter saying chuleria k
# to regular service meat good expected bad doesnt taste like smoke smoke house t

# %%
Text(lemmatized_words).collocations()
# Out:
# mac cheese; come back; pulled pork; plastic cutlery; onion ring; high
# expectation; hour half; frozen potato; run away; deaf ear; medium
# cooking; arab customer; year ago; poor quality; bad service;
# absolutely awful; minute late; recommend visiting; soft drink; didnt
# even

# %%
def text_process(review):
    nopunc = [char for char in review if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    return [word.lower() for word in nopunc.split()]

# %%
rev_text['clean_text_stopwords'] = rev_text['review_text'].apply(text_process)
rev_text
# Out:
#      index                                        review_text  \
# 0       94  (Translated by Google) Incredible food but the...
# 1      104  (Translated by Google) I've been there twice:\...
# 2      107  Coke with no gas, burned steak, disgusting chi...
# 3      112  (Translated by Google) We were there yesterday...
# 4      227  (Translated by Google) bad service\n\n(Origina...
# ..     ...                                                ...
# 104   1689                     Cold pulled pork, and dry ribs
# 105   1690  (Translated by Google) Cold, tasteless a pity....
# 106   1693  They really need to step up their game for it ...
# 107   1706  (Translated by Google) To not come back, as so...
# 108   1708  (Translated by Google) Excellent decoration, e...
#
#                                             clean_text  \
# 0    [incredible, food, service, leaves, lot, desir...
# 1    [ive, twice, first, took, wellcooked, santa, f...
# 2    [coke, gas, burned, steak, disgusting, chips, ...
# 3    [yesterday, wednesday, july, 20, first, asked,...
# 4                                       [bad, service]
# ..                                                 ...
# 104                    [cold, pulled, pork, dry, ribs]
# 105  [cold, tasteless, pity, place, nice, also, tak...
# 106  [really, need, step, game, work, come, back, q...
# 107  [come, back, soon, arrive, find, wall, large, ...
# 108  [excellent, decoration, excessive, waiting, ti...
#
#                                      clean_text_merged  \
# 0    incredible food service leaves lot desired 130...
# 1    ive twice first took wellcooked santa fe arriv...
# 2    coke gas burned steak disgusting chips bad qua...
# 3    yesterday wednesday july 20 first asked foods ...
# 4                                          bad service
# ..                                                 ...
# 104                          cold pulled pork dry ribs
# 105  cold tasteless pity place nice also take care ...
# 106  really need step game work come back quality s...
# 107  come back soon arrive find wall large panel le...
# 108  excellent decoration excessive waiting time 15...
#
#                                   clean_text_stopwords
# 0    [translated, by, google, incredible, food, but...
# 1    [translated, by, google, ive, been, there, twi...
# 2    [coke, with, no, gas, burned, steak, disgustin...
# 3    [translated, by, google, we, were, there, yest...
# 4    [translated, by, google, bad, service, origina...
# ..                                                 ...
# 104               [cold, pulled, pork, and, dry, ribs]
# 105  [translated, by, google, cold, tasteless, a, p...
# 106  [they, really, need, to, step, up, their, game...
# 107  [translated, by, google, to, not, come, back, ...
# 108  [translated, by, google, excellent, decoration...
#
# [109 rows x 5 columns]

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in all_reviews]
lemmatized_words
# Out:
# ['incredible',
#  'food',
#  'service',
#  'leaf',
#  'lot',
#  'desired',
#  '130',
#  'served',
#  'food',
#  'everything',
#  'ordered',
#  'took',
#  'forever',
#  'ive',
#  'twice',
#  'first',
#  'took',
#  'wellcooked',
#  'santa',
#  'fe',
#  'arrived',
#  'burnt',
#  'staff',
#  'attentive',
#  'customer',
#  'spoke',
#  'spanish',
#  'factor',
#  'linguistic',
#  'misunderstanding',
#  'asking',
#  'specifically',
#  'food',
#  'without',
#  'garlic',
#  'difficulty',
#  'digesting',
#  'deaf',
#  'ear',
#  'full',
#  'oil',
#  'chock',
#  'full',
#  'garlic',
#  'second',
#  'time',
#  'went',
#  'exactly',
#  'like',
#  'first',
#  'including',
#  'garlic',
#  'asking',
#  'santa',
#  'fe',
#  'medium',
#  'cooking',
#  'obviously',
#  'arrived',
#  'burnt',
#  'basically',
#  'would',
#  'go',
#  'back',
#  'staff',
#  'seem',
#  'annoyed',
#  'every',
#  'slightest',
#  'request',
#  'excellent',
#  'quality',
#  'food',
#  'unable',
#  'cook',
#  'requested',
#  'coke',
#  'gas',
#  'burned',
#  'steak',
#  'disgusting',
#  'chip',
#  'bad',
#  'quality',
#  'meat',
#  '70',
#  'fat',
#  'yesterday',
#  'wednesday',
#  'july',
#  '20',
#  'first',
#  'asked',
#  'food',
#  'people',
#  'gluten',
#  'intolerance',
#  'surprise',
#  'restaurant',
#  'name',
#  'located',
#  'street',
#  'many',
#  'visitor',
#  'told',
#  'nooo',
#  'food',
#  'crosscontaminated',
#  'well',
#  'seemed',
#  'people',
#  'restaurant',
#  'easy',
#  'clean',
#  'griddle',
#  'make',
#  'hamburger',
#  'thats',
#  'little',
#  'desire',
#  'work',
#  'people',
#  'intolerance',
#  'allergy',
#  'food',
#  'complain',
#  'cannot',
#  'allowed',
#  'need',
#  'desire',
#  'glove',
#  'clean',
#  'pan',
#  'customer',
#  'leaf',
#  'happy',
#  'complicated',
#  'need',
#  'like',
#  'job',
#  'cheer',
#  'bad',
#  'service',
#  'disappointing',
#  'put',
#  'hot',
#  'water',
#  'u',
#  'complained',
#  'told',
#  'u',
#  'cold',
#  'water',
#  'loaded',
#  'refrigerator',
#  '830',
#  'pm',
#  'night',
#  'seems',
#  'bad',
#  'management',
#  'cold',
#  'water',
#  'time',
#  'fair',
#  'attention',
#  'one',
#  'hamburger',
#  'completely',
#  'charred',
#  'onion',
#  'high',
#  'price',
#  'quality',
#  'attention',
#  'el',
#  'movil',
#  'em',
#  'va',
#  'portar',
#  'aqui',
#  'sol',
#  'utilitzen',
#  'bot',
#  'per',
#  'atraure',
#  'gent',
#  'hi',
#  'anat',
#  'pero',
#  'tampoc',
#  'hi',
#  'aniré',
#  'brisket',
#  'served',
#  'week',
#  'first',
#  'want',
#  'explain',
#  'give',
#  'one',
#  'star',
#  'two',
#  'year',
#  'ago',
#  'went',
#  'meat',
#  'melted',
#  'mouth',
#  'wonderful',
#  'quantity',
#  'large',
#  'ask',
#  'take',
#  'away',
#  'exquisite',
#  'flavor',
#  'fresh',
#  'two',
#  'year',
#  'ago',
#  'week',
#  'went',
#  'god',
#  'biggest',
#  'disappointment',
#  'tiny',
#  'amount',
#  'zero',
#  'taste',
#  'worst',
#  'soft',
#  'drink',
#  'ive',
#  'ever',
#  'life',
#  'mixture',
#  'water',
#  'sugar',
#  'turmeric',
#  'without',
#  'gas',
#  'supposedly',
#  'orange',
#  'one',
#  'rash',
#  'hand',
#  'left',
#  'want',
#  'fair',
#  'say',
#  'attention',
#  'bad',
#  'made',
#  'sad',
#  'dont',
#  'think',
#  'come',
#  'back',
#  'would',
#  'nice',
#  'went',
#  'back',
#  'beginning',
#  'dont',
#  'know',
#  'change',
#  'owner',
#  'decided',
#  'make',
#  'cut',
#  'everything',
#  'could',
#  'make',
#  'well',
#  'done',
#  'meat',
#  'first',
#  'time',
#  'made',
#  'wait',
#  '1',
#  'hour',
#  'food',
#  'friend',
#  'finished',
#  'eating',
#  'glass',
#  'pepsi',
#  'cost',
#  '35€',
#  'bad',
#  'service',
#  'high',
#  'price',
#  'good',
#  'food',
#  'bad',
#  'service',
#  'wrong',
#  'order',
#  'waiter',
#  'run',
#  'away',
#  'money',
#  'forgets',
#  'change',
#  'shame',
#  'delicious',
#  'food',
#  'dissapointed',
#  'place',
#  'cold',
#  'leave',
#  'jacket',
#  'seated',
#  'one',
#  'table',
#  'asked',
#  'move',
#  'stroller',
#  'saw',
#  'offered',
#  'u',
#  'first',
#  'table',
#  'let',
#  'tell',
#  'table',
#  'free',
#  'bothering',
#  'anyone',
#  'super',
#  'weird',
#  'food',
#  'ok',
#  'bit',
#  'dry',
#  'side',
#  'far',
#  'texas',
#  'similar',
#  'pepsi',
#  'without',
#  'bubble',
#  'idea',
#  'never',
#  'write',
#  'bad',
#  'review',
#  'stuck',
#  'bad',
#  'experience',
#  'served',
#  'u',
#  'piece',
#  'burnt',
#  'meat',
#  'turned',
#  'deaf',
#  'ear',
#  'grievance',
#  'unprofessional',
#  'staff',
#  'starting',
#  'bos',
#  'even',
#  'courage',
#  'ask',
#  'everything',
#  'went',
#  'well',
#  'avoided',
#  'carefully',
#  'p',
#  'asked',
#  'medium',
#  'cooking',
#  'well',
#  'still',
#  'waiting',
#  'served',
#  'wasnt',
#  'crowded',
#  'slow',
#  'service',
#  'really',
#  'average',
#  'food',
#  'menu',
#  'wonderful',
#  'dish',
#  'attract',
#  'lot',
#  'attention',
#  'served',
#  'food',
#  'terrible',
#  'food',
#  'american',
#  'flavor',
#  'anywhere',
#  'misleading',
#  'bbq',
#  'joint',
#  'it’s',
#  'basically',
#  'steak',
#  'house',
#  'brisket',
#  'available',
#  'day',
#  'week',
#  'maybe',
#  'weekaccording',
#  'waiter',
#  'rude',
#  'initially',
#  'salad',
#  'came',
#  'sautéed',
#  'veggie',
#  'stir',
#  'fried',
#  'almost',
#  '1',
#  'star',
#  'give',
#  'beef',
#  'patty',
#  'burger',
#  'ok',
#  'misleading',
#  'edited',
#  'review',
#  'real',
#  'truthful',
#  'since',
#  'read',
#  'owner',
#  'responded',
#  'trying',
#  'harsh',
#  'bad',
#  'behavior',
#  'staff',
#  'specially',
#  'arab',
#  'customer',
#  'get',
#  'bad',
#  'racism',
#  'staff',
#  'arab',
#  'recommend',
#  'visiting',
#  'reason',
#  'deliberately',
#  'create',
#  'problem',
#  'arab',
#  'customer',
#  'restaurant',
#  'worker',
#  'making',
#  'problem',
#  'arab',
#  'customer',
#  'rude',
#  'unfair',
#  'treatment',
#  'recommend',
#  'visiting',
#  'restaurant',
#  'hope',
#  'staff',
#  'improve',
#  'behavior',
#  'drank',
#  'cook',
#  'without',
#  'mask',
#  'waiter',
#  'didnt',
#  'rinse',
#  'dish',
#  'also',
#  'waited',
#  'almost',
#  '1',
#  'hour',
#  'food',
#  'brought',
#  'u',
#  'didnt',
#  'eat',
#  'badly',
#  'dont',
#  'think',
#  'truth',
#  'come',
#  'back',
#  'oh',
#  'expensive',
#  'place',
#  'truth',
#  'lack',
#  'lot',
#  'education',
#  'attend',
#  'bad',
#  'attention',
#  'experience',
#  'fatal',
#  'brought',
#  'u',
#  'dish',
#  'others',
#  'missing',
#  'brought',
#  'u',
#  'extra',
#  'drink',
#  'asking',
#  'napkin',
#  'brought',
#  'u',
#  'threw',
#  'away',
#  'account',
#  'time',
#  'paying',
#  'n',
#  'overcharging',
#  'thing',
#  'asked',
#  'glass',
#  'wine',
#  'wanted',
#  'charge',
#  'u',
#  'bottle',
#  'attention',
#  'fatal',
#  'part',
#  'group',
#  '10',
#  'people',
#  'return',
#  'scam',
#  'much',
#  'better',
#  'foster',
#  'hollywood',
#  'irony',
#  'cold',
#  'starter',
#  'regular',
#  'regular',
#  'meat',
#  'expensive',
#  'poor',
#  'quality',
#  'three',
#  'people',
#  'ate',
#  'three',
#  'found',
#  'burger',
#  'meat',
#  'compact',
#  'dry',
#  'didnt',
#  'look',
#  'like',
#  'black',
#  'angus',
#  'ordered',
#  'point',
#  'served',
#  'u',
#  'well',
#  'done',
#  'quality',
#  'meat',
#  'appreciated',
#  'waiting',
#  '1h',
#  'see',
#  'serve',
#  'people',
#  'entered',
#  'later',
#  'go',
#  'without',
#  'eating',
#  'best',
#  'tell',
#  'u',
#  'hope',
#  '10',
#  'minute',
#  'final',
#  'shot',
#  'consumption',
#  'charge',
#  'u',
#  '1h',
#  'nothing',
#  'recommendable',
#  'ive',
#  'going',
#  'long',
#  'time',
#  'already',
#  'twice',
#  'take',
#  'hour',
#  'serve',
#  'today',
#  'leave',
#  'without',
#  'eating',
#  'food',
#  'never',
#  'arrived',
#  'wont',
#  'back',
#  'slow',
#  'serving',
#  'hamburger',
#  'excessively',
#  'expensive',
#  'positive',
#  'point',
#  'highlight',
#  'nacho',
#  'unfortunately',
#  'burger',
#  'wasnt',
#  'hit',
#  'meat',
#  'wasnt',
#  'juicy',
#  'worst',
#  'food',
#  'couldnt',
#  'even',
#  'eat',
#  'anything',
#  'chip',
#  '🤢🤮',
#  'get',
#  'sick',
#  'eat',
#  'dinner',
#  '🤬',
#  '3',
#  'dry',
#  'half',
#  'rib',
#  'two',
#  'slice',
#  'brisquet',
#  '90',
#  'gram',
#  'fat',
#  'two',
#  'portion',
#  'potato',
#  'frozen',
#  'cane',
#  '24',
#  'euro',
#  'left',
#  'hungry',
#  'tourist',
#  'bet',
#  'pay',
#  'positive',
#  'recensions',
#  'impossible',
#  'site',
#  '4',
#  'star',
#  'ordered',
#  'california',
#  'burger',
#  'fry',
#  'fry',
#  'dry',
#  'even',
#  'mess',
#  'burger',
#  'made',
#  'low',
#  'quality',
#  'meat',
#  'texture',
#  'taste',
#  'bbq',
#  'sauce',
#  'super',
#  'market',
#  'quality',
#  'description',
#  'restaurant',
#  'say',
#  'made',
#  'soul',
#  'made',
#  'laugh',
#  'opinion',
#  'low',
#  'quality',
#  'food',
#  'tourist',
#  'marketing',
#  'concept',
#  'interior',
#  'design',
#  'made',
#  'professionally',
#  'pull',
#  'pork',
#  'rib',
#  'tomahawk',
#  'basically',
#  'main',
#  'dish',
#  'restaurant',
#  'like',
#  'need',
#  'supply',
#  'holiday',
#  'season',
#  'disappointed',
#  'seeing',
#  'advertising',
#  'instagram',
#  'good',
#  'review',
#  'around',
#  'clear',
#  'wanted',
#  'go',
#  'try',
#  'tomahawk',
#  'leave',
#  'sample',
#  'disappointment',
#  'whole',
#  'center',
#  'drier',
#  'eye',
#  'oneeyed',
#  'man',
#  'took',
#  'half',
#  'hour',
#  'serve',
#  'u',
#  'despite',
#  'fact',
#  'time',
#  'hardly',
#  'people',
#  'could',
#  'enjoy',
#  'food',
#  'either',
#  'two',
#  'photographer',
#  'taking',
#  'granted',
#  'time',
#  'made',
#  'uncomfortable',
#  'second',
#  'time',
#  'wont',
#  'third',
#  'real',
#  'shame',
#  'like',
#  'gave',
#  'heartburn',
#  'day',
#  'product',
#  'relief',
#  'downgrading',
#  'review',
#  '1',
#  'star',
#  'due',
#  'terrible',
#  'response',
#  'owner',
#  'based',
#  'response',
#  'theyre',
#  'basically',
#  'saying',
#  'minute',
#  'late',
#  'punished',
#  'terrible',
#  'service',
#  'table',
#  'cold',
#  'along',
#  'cold',
#  'food',
#  'forget',
#  'folk',
#  'get',
#  'better',
#  'dont',
#  'love',
#  'technology',
#  'please',
#  'see',
#  'timeline',
#  'image',
#  'attached',
#  'clearly',
#  'show',
#  'never',
#  'anywhere',
#  'near',
#  '25',
#  'minute',
#  'late',
#  'minute',
#  'logged',
#  'time',
#  'hey',
#  'maybe',
#  'dont',
#  'leave',
#  'customer',
#  'waiting',
#  'around',
#  'someone',
#  'eventually',
#  'seat',
#  'would',
#  'actually',
#  'time',
#  'oh',
#  'btw',
#  'maybe',
#  'go',
#  'speak',
#  'waiter',
#  'ask',
#  'nice',
#  'im',
#  '100',
#  'sure',
#  'waiter',
#  'disagree',
#  'never',
#  'blamed',
#  'bad',
#  'experience',
#  'poor',
#  'guy',
#  'simply',
#  'overwhelmed',
#  'due',
#  'bad',
#  'management',
#  'got',
#  'tip',
#  'u',
#  'regardless',
#  'clearly',
#  'enough',
#  'staff',
#  'amount',
#  'people',
#  'terrible',
#  'quality',
#  'control',
#  'serve',
#  'cold',
#  'food',
#  'clearly',
#  'cannot',
#  'accept',
#  'criticism',
#  'either',
#  'making',
#  'story',
#  '25',
#  '40',
#  'min',
#  'depending',
#  'wording',
#  'minute',
#  'late',
#  'cheek',
#  'imply',
#  'nice',
#  'customer',
#  'leaving',
#  'honest',
#  'feedback',
#  'oh',
#  'well',
#  'sangria',
#  'carafe',
#  'broke',
#  'spilled',
#  'apology',
#  'staff',
#  'manager',
#  'blamed',
#  'breaking',
#  'glass',
#  'burger',
#  'absolutely',
#  'awful',
#  'steak',
#  'gad',
#  'fat',
#  'meat',
#  'absolutely',
#  'worse',
#  'service',
#  'i’ve',
#  'ever',
#  'server',
#  'i’ve',
#  'never',
#  'situation',
#  'like',
#  'sangria',
#  'broke',
#  'still',
#  'charged',
#  'u',
#  'sangria',
#  'absolutely',
#  'awful',
#  'please',
#  'don’t',
#  'waste',
#  'time',
#  'money',
#  'food',
#  'overly',
#  'simple',
#  'overly',
#  'greasy',
#  'rude',
#  'staff',
#  'id',
#  'say',
#  'stay',
#  'away',
#  'go',
#  'somewhere',
#  'else',
#  'dry',
#  'hard',
#  'chew',
#  'fry',
#  'poor',
#  'quality',
#  'meat',
#  'burger',
#  'beer',
#  'alright',
#  'though',
#  'staff',
#  'friendly',
#  'bad',
#  'service',
#  'placed',
#  'order',
#  'one',
#  'hour',
#  'ago',
#  'lost',
#  'dont',
#  'plan',
#  'provide',
#  'either',
#  'talked',
#  'waiter',
#  'several',
#  'time',
#  'never',
#  'restaurant',
#  'penous',
#  'service…',
#  'two',
#  'time',
#  ...]
