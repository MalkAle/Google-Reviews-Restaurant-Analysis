# %%
import pandas as pd
import numpy as np

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt
#%matplotlib inline

# %%
from datetime import datetime, timedelta
from dateutil import relativedelta

# %%
import string

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.text import Text 
from nltk.collocations import *
from nltk.corpus import wordnet

# %%
df = pd.read_csv("Smoke_House_Google_Reviews.csv")

# %%
df.drop(['query', 'name', 'google_id', 'place_id', 'location_link',
       'reviews_link', 'reviews_per_score', 'reviews','rating','review_id',
       'author_link','author_image','review_img_url',
       'review_link','reviews_id'],axis=1,inplace=True)

# %%
df['text_yn'] = df['review_text'].apply(lambda x: 'no' if x!=x else 'yes')
df['anwser_yn'] = df['owner_answer'].apply(lambda x: 'no' if x!=x else 'yes')
print(df['text_yn'].value_counts())
print(df['anwser_yn'].value_counts())

df[df['text_yn']=='yes']['review_text'].isna().value_counts()

df.head()
# Out:
# yes    1143
# no      579
# Name: text_yn, dtype: int64
# no     1180
# yes     542
# Name: anwser_yn, dtype: int64
#         author_title              author_id  \
# 0     Christian Díaz  118290890328226276251
# 1  Gabriela Santiana  106821844711863729721
# 2         Meir Cohen  104714702665944371857
# 3          kaka kaka  101906364734052474176
# 4   Alberto Martinez  108348994920795296705
#
#                                          review_text owner_answer  \
# 0  (Translated by Google) As always a 10 for this...          NaN
# 1  Delicioso todo.. seguramente repetiremos para ...          NaN
# 2  Great restaurant, great food, good price, slow...          NaN
# 3  Está demasiado bueno la calidad es increíble, ...          NaN
# 4  (Translated by Google) American food restauran...          NaN
#
#    owner_answer_timestamp owner_answer_timestamp_datetime_utc  review_rating  \
# 0                     NaN                                 NaN              5
# 1                     NaN                                 NaN              5
# 2                     NaN                                 NaN              4
# 3                     NaN                                 NaN              5
# 4                     NaN                                 NaN              5
#
#    review_timestamp  review_datetime_utc  review_likes text_yn anwser_yn
# 0        1661161121  08/22/2022 09:38:41             0     yes        no
# 1        1661152489  08/22/2022 07:14:49             1     yes        no
# 2        1661120357  08/21/2022 22:19:17             0     yes        no
# 3        1661114131  08/21/2022 20:35:31             1     yes        no
# 4        1661097601  08/21/2022 16:00:01             1     yes        no

# %%
rev_text = df[df['text_yn']=='yes']
rev_text = rev_text[rev_text['review_rating'] <= 2]
rev_text = pd.DataFrame(rev_text['review_text'])
rev_text.reset_index(inplace=True)

# %%
rev_text.isna().value_counts()
# Out:
# index  review_text
# False  False          109
# dtype: int64

# %%
rev_text.head()
# Out:
#    index                                        review_text
# 0     94  (Translated by Google) Incredible food but the...
# 1    104  (Translated by Google) I've been there twice:\...
# 2    107  Coke with no gas, burned steak, disgusting chi...
# 3    112  (Translated by Google) We were there yesterday...
# 4    227  (Translated by Google) bad service\n\n(Origina...

# %%
rev_text.iloc[0]
# Out:
# index                                                         94
# review_text    (Translated by Google) Incredible food but the...
# Name: 0, dtype: object

# %%
#rev_text['review_text'] = rev_text['review_text'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
#rev_text.head(3)

# %%
#string.punctuation

# %%
#stopwords.words('english')

# %%
'us' in stopwords.words('english')
# Out:
# False

# %%
stopwords.words('english')#.append('us')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
def text_process(review):
    nopunc = [char for char in review if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    nopunc = [word.lower() for word in nopunc.split()]
    return [word for word in nopunc if word.lower() not in stopwords.words('english')]

# %%
rev_text['clean_text'] = rev_text['review_text'].apply(text_process)

# %%
#rev_text['text_split'] = rev_text['review_text'].apply(lambda x: str(x).split())

# %%
rev_text.head()
# Out:
#    index                                        review_text  \
# 0     94  (Translated by Google) Incredible food but the...
# 1    104  (Translated by Google) I've been there twice:\...
# 2    107  Coke with no gas, burned steak, disgusting chi...
# 3    112  (Translated by Google) We were there yesterday...
# 4    227  (Translated by Google) bad service\n\n(Origina...
#
#                                           clean_text
# 0  [translated, google, incredible, food, service...
# 1  [translated, google, ive, twice, first, took, ...
# 2  [coke, gas, burned, steak, disgusting, chips, ...
# 3  [translated, google, yesterday, wednesday, jul...
# 4  [translated, google, bad, service, original, ש...

# %%
def cleaner(split):
    for string in ['translated','google']:
        while string in split:
            split.remove(string)
            
rev_text['clean_text'].apply(cleaner)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 104    None
# 105    None
# 106    None
# 107    None
# 108    None
# Name: clean_text, Length: 109, dtype: object

# %%
#rev_text

# %%
def cleaner2(review):
    while 'original' in review:
        review.index('original')
        del review[review.index('original'):]
            
rev_text['clean_text'].apply(cleaner2)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 104    None
# 105    None
# 106    None
# 107    None
# 108    None
# Name: clean_text, Length: 109, dtype: object

# %%
rev_text.head(3)
# Out:
#    index                                        review_text  \
# 0     94  (Translated by Google) Incredible food but the...
# 1    104  (Translated by Google) I've been there twice:\...
# 2    107  Coke with no gas, burned steak, disgusting chi...
#
#                                           clean_text
# 0  [incredible, food, service, leaves, lot, desir...
# 1  [ive, twice, first, took, wellcooked, santa, f...
# 2  [coke, gas, burned, steak, disgusting, chips, ...

# %%
rev_text
# Out:
#      index                                        review_text  \
# 0       94  (Translated by Google) Incredible food but the...
# 1      104  (Translated by Google) I've been there twice:\...
# 2      107  Coke with no gas, burned steak, disgusting chi...
# 3      112  (Translated by Google) We were there yesterday...
# 4      227  (Translated by Google) bad service\n\n(Origina...
# ..     ...                                                ...
# 104   1689                     Cold pulled pork, and dry ribs
# 105   1690  (Translated by Google) Cold, tasteless a pity....
# 106   1693  They really need to step up their game for it ...
# 107   1706  (Translated by Google) To not come back, as so...
# 108   1708  (Translated by Google) Excellent decoration, e...
#
#                                             clean_text
# 0    [incredible, food, service, leaves, lot, desir...
# 1    [ive, twice, first, took, wellcooked, santa, f...
# 2    [coke, gas, burned, steak, disgusting, chips, ...
# 3    [yesterday, wednesday, july, 20, first, asked,...
# 4                                       [bad, service]
# ..                                                 ...
# 104                    [cold, pulled, pork, dry, ribs]
# 105  [cold, tasteless, pity, place, nice, also, tak...
# 106  [really, need, step, game, work, come, back, q...
# 107  [come, back, soon, arrive, find, wall, large, ...
# 108  [excellent, decoration, excessive, waiting, ti...
#
# [109 rows x 3 columns]

# %%
review_text = rev_text['clean_text'].to_list()

# %%
all_reviews = []

for review in review_text:
    all_reviews = all_reviews + review

all_reviews
# Out:
# ['incredible',
#  'food',
#  'service',
#  'leaves',
#  'lot',
#  'desired',
#  '130',
#  'served',
#  'food',
#  'everything',
#  'ordered',
#  'took',
#  'forever',
#  'ive',
#  'twice',
#  'first',
#  'took',
#  'wellcooked',
#  'santa',
#  'fe',
#  'arrived',
#  'burnt',
#  'staff',
#  'attentive',
#  'customer',
#  'spoke',
#  'spanish',
#  'factor',
#  'linguistic',
#  'misunderstanding',
#  'asking',
#  'specifically',
#  'foods',
#  'without',
#  'garlic',
#  'difficulty',
#  'digesting',
#  'deaf',
#  'ears',
#  'full',
#  'oil',
#  'chock',
#  'full',
#  'garlic',
#  'second',
#  'time',
#  'went',
#  'exactly',
#  'like',
#  'first',
#  'including',
#  'garlic',
#  'asking',
#  'santa',
#  'fe',
#  'medium',
#  'cooking',
#  'obviously',
#  'arrived',
#  'burnt',
#  'basically',
#  'would',
#  'go',
#  'back',
#  'staff',
#  'seem',
#  'annoyed',
#  'every',
#  'slightest',
#  'request',
#  'excellent',
#  'quality',
#  'food',
#  'unable',
#  'cook',
#  'requested',
#  'coke',
#  'gas',
#  'burned',
#  'steak',
#  'disgusting',
#  'chips',
#  'bad',
#  'quality',
#  'meat',
#  '70',
#  'fat',
#  'yesterday',
#  'wednesday',
#  'july',
#  '20',
#  'first',
#  'asked',
#  'foods',
#  'people',
#  'gluten',
#  'intolerance',
#  'surprise',
#  'restaurant',
#  'name',
#  'located',
#  'street',
#  'many',
#  'visitors',
#  'told',
#  'nooo',
#  'food',
#  'crosscontaminated',
#  'well',
#  'seemed',
#  'people',
#  'restaurant',
#  'easy',
#  'clean',
#  'griddle',
#  'make',
#  'hamburger',
#  'thats',
#  'little',
#  'desire',
#  'work',
#  'people',
#  'intolerances',
#  'allergies',
#  'food',
#  'complain',
#  'cannot',
#  'allowed',
#  'need',
#  'desire',
#  'gloves',
#  'clean',
#  'pan',
#  'customer',
#  'leaves',
#  'happy',
#  'complicated',
#  'need',
#  'like',
#  'job',
#  'cheers',
#  'bad',
#  'service',
#  'disappointing',
#  'put',
#  'hot',
#  'water',
#  'us',
#  'complained',
#  'told',
#  'us',
#  'cold',
#  'water',
#  'loaded',
#  'refrigerators',
#  '830',
#  'pm',
#  'night',
#  'seems',
#  'bad',
#  'management',
#  'cold',
#  'water',
#  'time',
#  'fair',
#  'attention',
#  'one',
#  'hamburgers',
#  'completely',
#  'charred',
#  'onion',
#  'high',
#  'price',
#  'quality',
#  'attention',
#  'el',
#  'movil',
#  'em',
#  'va',
#  'portar',
#  'aqui',
#  'sol',
#  'utilitzen',
#  'bots',
#  'per',
#  'atraure',
#  'gent',
#  'hi',
#  'anat',
#  'pero',
#  'tampoc',
#  'hi',
#  'aniré',
#  'brisket',
#  'served',
#  'week',
#  'first',
#  'want',
#  'explain',
#  'give',
#  'one',
#  'star',
#  'two',
#  'years',
#  'ago',
#  'went',
#  'meat',
#  'melted',
#  'mouth',
#  'wonderful',
#  'quantities',
#  'large',
#  'ask',
#  'take',
#  'away',
#  'exquisite',
#  'flavor',
#  'fresh',
#  'two',
#  'years',
#  'ago',
#  'weeks',
#  'went',
#  'god',
#  'biggest',
#  'disappointment',
#  'tiny',
#  'amounts',
#  'zero',
#  'taste',
#  'worst',
#  'soft',
#  'drink',
#  'ive',
#  'ever',
#  'life',
#  'mixture',
#  'water',
#  'sugar',
#  'turmeric',
#  'without',
#  'gas',
#  'supposedly',
#  'orange',
#  'ones',
#  'rash',
#  'hands',
#  'left',
#  'want',
#  'fair',
#  'say',
#  'attention',
#  'bad',
#  'made',
#  'sad',
#  'dont',
#  'think',
#  'come',
#  'back',
#  'would',
#  'nice',
#  'went',
#  'back',
#  'beginnings',
#  'dont',
#  'know',
#  'change',
#  'owners',
#  'decided',
#  'make',
#  'cuts',
#  'everything',
#  'could',
#  'make',
#  'well',
#  'done',
#  'meat',
#  'first',
#  'time',
#  'made',
#  'wait',
#  '1',
#  'hour',
#  'food',
#  'friends',
#  'finished',
#  'eating',
#  'glass',
#  'pepsi',
#  'costs',
#  '35€',
#  'bad',
#  'service',
#  'high',
#  'price',
#  'good',
#  'food',
#  'bad',
#  'service',
#  'wrong',
#  'orders',
#  'waiter',
#  'runs',
#  'away',
#  'money',
#  'forgets',
#  'change',
#  'shame',
#  'delicious',
#  'food',
#  'dissapointed',
#  'place',
#  'cold',
#  'leave',
#  'jackets',
#  'seated',
#  'one',
#  'table',
#  'asked',
#  'move',
#  'stroller',
#  'saw',
#  'offered',
#  'us',
#  'first',
#  'table',
#  'let',
#  'tell',
#  'tables',
#  'free',
#  'bothering',
#  'anyone',
#  'super',
#  'weird',
#  'food',
#  'ok',
#  'bit',
#  'dry',
#  'side',
#  'far',
#  'texas',
#  'similar',
#  'pepsi',
#  'without',
#  'bubbles',
#  'idea',
#  'never',
#  'write',
#  'bad',
#  'reviews',
#  'stuck',
#  'bad',
#  'experience',
#  'served',
#  'us',
#  'piece',
#  'burnt',
#  'meat',
#  'turned',
#  'deaf',
#  'ear',
#  'grievances',
#  'unprofessional',
#  'staff',
#  'starting',
#  'boss',
#  'even',
#  'courage',
#  'ask',
#  'everything',
#  'went',
#  'well',
#  'avoided',
#  'carefully',
#  'ps',
#  'asked',
#  'medium',
#  'cooking',
#  'well',
#  'still',
#  'waiting',
#  'served',
#  'wasnt',
#  'crowded',
#  'slow',
#  'service',
#  'really',
#  'average',
#  'food',
#  'menu',
#  'wonderful',
#  'dishes',
#  'attract',
#  'lot',
#  'attention',
#  'served',
#  'food',
#  'terrible',
#  'food',
#  'american',
#  'flavor',
#  'anywhere',
#  'misleading',
#  'bbq',
#  'joint',
#  'it’s',
#  'basically',
#  'steak',
#  'house',
#  'brisket',
#  'available',
#  'days',
#  'week',
#  'maybe',
#  'weekaccording',
#  'waiter',
#  'rude',
#  'initially',
#  'salad',
#  'came',
#  'sautéed',
#  'veggies',
#  'stir',
#  'fried',
#  'almost',
#  '1',
#  'star',
#  'give',
#  'beef',
#  'patty',
#  'burger',
#  'ok',
#  'misleading',
#  'edited',
#  'review',
#  'real',
#  'truthful',
#  'since',
#  'read',
#  'owner',
#  'responded',
#  'trying',
#  'harsh',
#  'bad',
#  'behavior',
#  'staff',
#  'specially',
#  'arabs',
#  'customers',
#  'get',
#  'bad',
#  'racism',
#  'staffs',
#  'arabs',
#  'recommend',
#  'visiting',
#  'reason',
#  'deliberately',
#  'create',
#  'problems',
#  'arabs',
#  'customers',
#  'restaurant',
#  'workers',
#  'making',
#  'problems',
#  'arab',
#  'customers',
#  'rude',
#  'unfair',
#  'treatment',
#  'recommend',
#  'visiting',
#  'restaurant',
#  'hope',
#  'staff',
#  'improve',
#  'behavior',
#  'drank',
#  'cook',
#  'without',
#  'mask',
#  'waiters',
#  'didnt',
#  'rinse',
#  'dishes',
#  'also',
#  'waited',
#  'almost',
#  '1',
#  'hour',
#  'food',
#  'brought',
#  'us',
#  'didnt',
#  'eat',
#  'badly',
#  'dont',
#  'think',
#  'truth',
#  'comes',
#  'back',
#  'oh',
#  'expensive',
#  'place',
#  'truth',
#  'lack',
#  'lot',
#  'education',
#  'attend',
#  'bad',
#  'attention',
#  'experience',
#  'fatal',
#  'brought',
#  'us',
#  'dishes',
#  'others',
#  'missing',
#  'brought',
#  'us',
#  'extra',
#  'drinks',
#  'asking',
#  'napkins',
#  'brought',
#  'us',
#  'threw',
#  'away',
#  'account',
#  'time',
#  'paying',
#  'ns',
#  'overcharging',
#  'things',
#  'asked',
#  'glass',
#  'wine',
#  'wanted',
#  'charge',
#  'us',
#  'bottle',
#  'attention',
#  'fatal',
#  'part',
#  'group',
#  '10',
#  'people',
#  'return',
#  'scam',
#  'much',
#  'better',
#  'foster',
#  'hollywood',
#  'irony',
#  'cold',
#  'starters',
#  'regular',
#  'regular',
#  'meat',
#  'expensive',
#  'poor',
#  'quality',
#  'three',
#  'people',
#  'ate',
#  'three',
#  'found',
#  'burger',
#  'meat',
#  'compact',
#  'dry',
#  'didnt',
#  'look',
#  'like',
#  'black',
#  'angus',
#  'ordered',
#  'point',
#  'served',
#  'us',
#  'well',
#  'done',
#  'quality',
#  'meat',
#  'appreciated',
#  'waiting',
#  '1h',
#  'see',
#  'serve',
#  'people',
#  'entered',
#  'later',
#  'go',
#  'without',
#  'eating',
#  'best',
#  'tell',
#  'us',
#  'hope',
#  '10',
#  'minutes',
#  'final',
#  'shot',
#  'consumptions',
#  'charge',
#  'us',
#  '1h',
#  'nothing',
#  'recommendable',
#  'ive',
#  'going',
#  'long',
#  'time',
#  'already',
#  'twice',
#  'takes',
#  'hour',
#  'serve',
#  'today',
#  'leave',
#  'without',
#  'eating',
#  'food',
#  'never',
#  'arrived',
#  'wont',
#  'back',
#  'slow',
#  'serving',
#  'hamburgers',
#  'excessively',
#  'expensive',
#  'positive',
#  'point',
#  'highlight',
#  'nachos',
#  'unfortunately',
#  'burger',
#  'wasnt',
#  'hit',
#  'meat',
#  'wasnt',
#  'juicy',
#  'worst',
#  'food',
#  'couldnt',
#  'even',
#  'eat',
#  'anything',
#  'chips',
#  '🤢🤮',
#  'get',
#  'sick',
#  'eat',
#  'dinner',
#  '🤬',
#  '3',
#  'dry',
#  'half',
#  'ribs',
#  'two',
#  'slices',
#  'brisquet',
#  '90',
#  'grams',
#  'fat',
#  'two',
#  'portions',
#  'potatoes',
#  'frozen',
#  'cane',
#  '24',
#  'euros',
#  'left',
#  'hungry',
#  'tourists',
#  'bet',
#  'pay',
#  'positive',
#  'recensions',
#  'impossible',
#  'site',
#  '4',
#  'stars',
#  'ordered',
#  'california',
#  'burger',
#  'fries',
#  'fries',
#  'dry',
#  'even',
#  'mess',
#  'burger',
#  'made',
#  'low',
#  'quality',
#  'meat',
#  'texture',
#  'taste',
#  'bbq',
#  'sauce',
#  'super',
#  'market',
#  'quality',
#  'description',
#  'restaurant',
#  'says',
#  'made',
#  'soul',
#  'made',
#  'laugh',
#  'opinion',
#  'low',
#  'quality',
#  'food',
#  'tourists',
#  'marketing',
#  'concept',
#  'interior',
#  'design',
#  'made',
#  'professionally',
#  'pull',
#  'pork',
#  'ribs',
#  'tomahawks',
#  'basically',
#  'main',
#  'dishes',
#  'restaurant',
#  'like',
#  'needs',
#  'supplies',
#  'holidays',
#  'season',
#  'disappointed',
#  'seeing',
#  'advertising',
#  'instagram',
#  'good',
#  'reviews',
#  'around',
#  'clear',
#  'wanted',
#  'go',
#  'try',
#  'tomahawk',
#  'leave',
#  'sample',
#  'disappointment',
#  'whole',
#  'center',
#  'drier',
#  'eye',
#  'oneeyed',
#  'man',
#  'took',
#  'half',
#  'hour',
#  'serve',
#  'us',
#  'despite',
#  'fact',
#  'time',
#  'hardly',
#  'people',
#  'could',
#  'enjoy',
#  'food',
#  'either',
#  'two',
#  'photographers',
#  'taking',
#  'granted',
#  'time',
#  'made',
#  'uncomfortable',
#  'second',
#  'time',
#  'wont',
#  'third',
#  'real',
#  'shame',
#  'like',
#  'gave',
#  'heartburn',
#  'day',
#  'product',
#  'relieves',
#  'downgrading',
#  'review',
#  '1',
#  'star',
#  'due',
#  'terrible',
#  'response',
#  'owner',
#  'based',
#  'response',
#  'theyre',
#  'basically',
#  'saying',
#  'minutes',
#  'late',
#  'punished',
#  'terrible',
#  'service',
#  'table',
#  'cold',
#  'along',
#  'cold',
#  'food',
#  'forget',
#  'folks',
#  'gets',
#  'better',
#  'dont',
#  'love',
#  'technology',
#  'please',
#  'see',
#  'timeline',
#  'image',
#  'attached',
#  'clearly',
#  'shows',
#  'never',
#  'anywhere',
#  'near',
#  '25',
#  'minutes',
#  'late',
#  'minutes',
#  'logged',
#  'time',
#  'hey',
#  'maybe',
#  'dont',
#  'leave',
#  'customers',
#  'waiting',
#  'around',
#  'someone',
#  'eventually',
#  'seat',
#  'would',
#  'actually',
#  'time',
#  'oh',
#  'btw',
#  'maybe',
#  'go',
#  'speak',
#  'waiter',
#  'ask',
#  'nice',
#  'im',
#  '100',
#  'sure',
#  'waiter',
#  'disagree',
#  'never',
#  'blamed',
#  'bad',
#  'experience',
#  'poor',
#  'guy',
#  'simply',
#  'overwhelmed',
#  'due',
#  'bad',
#  'management',
#  'got',
#  'tip',
#  'us',
#  'regardless',
#  'clearly',
#  'enough',
#  'staff',
#  'amount',
#  'people',
#  'terrible',
#  'quality',
#  'control',
#  'serve',
#  'cold',
#  'food',
#  'clearly',
#  'cannot',
#  'accept',
#  'criticism',
#  'either',
#  'making',
#  'stories',
#  '25',
#  '40',
#  'min',
#  'depending',
#  'wording',
#  'minutes',
#  'late',
#  'cheek',
#  'imply',
#  'nice',
#  'customers',
#  'leaving',
#  'honest',
#  'feedback',
#  'oh',
#  'well',
#  'sangria',
#  'carafe',
#  'broke',
#  'spilled',
#  'apology',
#  'staff',
#  'manager',
#  'blamed',
#  'breaking',
#  'glass',
#  'burger',
#  'absolutely',
#  'awful',
#  'steak',
#  'gad',
#  'fat',
#  'meat',
#  'absolutely',
#  'worse',
#  'service',
#  'i’ve',
#  'ever',
#  'server',
#  'i’ve',
#  'never',
#  'situation',
#  'like',
#  'sangria',
#  'broke',
#  'still',
#  'charged',
#  'us',
#  'sangria',
#  'absolutely',
#  'awful',
#  'please',
#  'don’t',
#  'waste',
#  'time',
#  'money',
#  'food',
#  'overly',
#  'simple',
#  'overly',
#  'greasy',
#  'rude',
#  'staff',
#  'id',
#  'say',
#  'stay',
#  'away',
#  'go',
#  'somewhere',
#  'else',
#  'dry',
#  'hard',
#  'chew',
#  'fries',
#  'poor',
#  'quality',
#  'meat',
#  'burger',
#  'beer',
#  'alright',
#  'though',
#  'staff',
#  'friendly',
#  'bad',
#  'service',
#  'placed',
#  'order',
#  'one',
#  'hour',
#  'ago',
#  'lost',
#  'dont',
#  'plan',
#  'provide',
#  'either',
#  'talked',
#  'waiters',
#  'several',
#  'times',
#  'never',
#  'restaurant',
#  'penous',
#  'service…',
#  'two',
#  'times',
#  ...]

# %%
all_reviews_joined = ' '.join(all_reviews)
all_reviews_joined
# Out:
# 'incredible food service leaves lot desired 130 served food everything ordered took forever ive twice first took wellcooked santa fe arrived burnt staff attentive customer spoke spanish factor linguistic misunderstanding asking specifically foods without garlic difficulty digesting deaf ears full oil chock full garlic second time went exactly like first including garlic asking santa fe medium cooking obviously arrived burnt basically would go back staff seem annoyed every slightest request excellent quality food unable cook requested coke gas burned steak disgusting chips bad quality meat 70 fat yesterday wednesday july 20 first asked foods people gluten intolerance surprise restaurant name located street many visitors told nooo food crosscontaminated well seemed people restaurant easy clean griddle make hamburger thats little desire work people intolerances allergies food complain cannot allowed need desire gloves clean pan customer leaves happy complicated need like job cheers bad service disappointing put hot water us complained told us cold water loaded refrigerators 830 pm night seems bad management cold water time fair attention one hamburgers completely charred onion high price quality attention el movil em va portar aqui sol utilitzen bots per atraure gent hi anat pero tampoc hi aniré brisket served week first want explain give one star two years ago went meat melted mouth wonderful quantities large ask take away exquisite flavor fresh two years ago weeks went god biggest disappointment tiny amounts zero taste worst soft drink ive ever life mixture water sugar turmeric without gas supposedly orange ones rash hands left want fair say attention bad made sad dont think come back would nice went back beginnings dont know change owners decided make cuts everything could make well done meat first time made wait 1 hour food friends finished eating glass pepsi costs 35€ bad service high price good food bad service wrong orders waiter runs away money forgets change shame delicious food dissapointed place cold leave jackets seated one table asked move stroller saw offered us first table let tell tables free bothering anyone super weird food ok bit dry side far texas similar pepsi without bubbles idea never write bad reviews stuck bad experience served us piece burnt meat turned deaf ear grievances unprofessional staff starting boss even courage ask everything went well avoided carefully ps asked medium cooking well still waiting served wasnt crowded slow service really average food menu wonderful dishes attract lot attention served food terrible food american flavor anywhere misleading bbq joint it’s basically steak house brisket available days week maybe weekaccording waiter rude initially salad came sautéed veggies stir fried almost 1 star give beef patty burger ok misleading edited review real truthful since read owner responded trying harsh bad behavior staff specially arabs customers get bad racism staffs arabs recommend visiting reason deliberately create problems arabs customers restaurant workers making problems arab customers rude unfair treatment recommend visiting restaurant hope staff improve behavior drank cook without mask waiters didnt rinse dishes also waited almost 1 hour food brought us didnt eat badly dont think truth comes back oh expensive place truth lack lot education attend bad attention experience fatal brought us dishes others missing brought us extra drinks asking napkins brought us threw away account time paying ns overcharging things asked glass wine wanted charge us bottle attention fatal part group 10 people return scam much better foster hollywood irony cold starters regular regular meat expensive poor quality three people ate three found burger meat compact dry didnt look like black angus ordered point served us well done quality meat appreciated waiting 1h see serve people entered later go without eating best tell us hope 10 minutes final shot consumptions charge us 1h nothing recommendable ive  ...

# %%
#nltk.pos_tag(all_reviews)

# %%
#stemmer = PorterStemmer()
#stemmed_words = [stemmer.stem(word) for word in all_reviews]
#stemmed_words

# %%
#pd.Series(stemmed_words).value_counts().head(10)

# %%
lemmatizer = WordNetLemmatizer()
#lemmatized_words = [lemmatizer.lemmatize(word) for word in all_reviews]
#lemmatized_words

# %%
pos_tags = ['J','V','N','R']

pos_filtered = [pos_tuple for pos_tuple in lemmatized_reviews if pos_tuple[1] in pos]
pos_filtered

# %%
def nltk_pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:          
        return None

# %%
def lemmatize_reviews(reviews):

    nltk_tagged = nltk.pos_tag(nltk.word_tokenize(reviews))  
    wordnet_tagged = map(lambda x: (x[0], nltk_pos_tagger(x[1])), nltk_tagged)
    lemmatized_reviews = []
    for word, tag in wordnet_tagged:
        if tag is None:
            lemmatized_reviews.append(word)
        else:        
            lemmatized_reviews.append(lemmatizer.lemmatize(word, tag))
    return lemmatized_reviews

# %%
lemmatize_reviews('joined')
# Out:
# ['join']

# %%
lemmatized_reviews = lemmatize_reviews(all_reviews_joined)

# %%
lemmatized_reviews
# Out:
# ['incredible',
#  'food',
#  'service',
#  'leave',
#  'lot',
#  'desire',
#  '130',
#  'serve',
#  'food',
#  'everything',
#  'order',
#  'take',
#  'forever',
#  'ive',
#  'twice',
#  'first',
#  'take',
#  'wellcooked',
#  'santa',
#  'fe',
#  'arrive',
#  'burnt',
#  'staff',
#  'attentive',
#  'customer',
#  'speak',
#  'spanish',
#  'factor',
#  'linguistic',
#  'misunderstanding',
#  'ask',
#  'specifically',
#  'food',
#  'without',
#  'garlic',
#  'difficulty',
#  'digest',
#  'deaf',
#  'ear',
#  'full',
#  'oil',
#  'chock',
#  'full',
#  'garlic',
#  'second',
#  'time',
#  'go',
#  'exactly',
#  'like',
#  'first',
#  'include',
#  'garlic',
#  'ask',
#  'santa',
#  'fe',
#  'medium',
#  'cook',
#  'obviously',
#  'arrive',
#  'burnt',
#  'basically',
#  'would',
#  'go',
#  'back',
#  'staff',
#  'seem',
#  'annoy',
#  'every',
#  'slight',
#  'request',
#  'excellent',
#  'quality',
#  'food',
#  'unable',
#  'cook',
#  'request',
#  'coke',
#  'gas',
#  'burn',
#  'steak',
#  'disgust',
#  'chip',
#  'bad',
#  'quality',
#  'meat',
#  '70',
#  'fat',
#  'yesterday',
#  'wednesday',
#  'july',
#  '20',
#  'first',
#  'ask',
#  'food',
#  'people',
#  'gluten',
#  'intolerance',
#  'surprise',
#  'restaurant',
#  'name',
#  'locate',
#  'street',
#  'many',
#  'visitor',
#  'tell',
#  'nooo',
#  'food',
#  'crosscontaminated',
#  'well',
#  'seemed',
#  'people',
#  'restaurant',
#  'easy',
#  'clean',
#  'griddle',
#  'make',
#  'hamburger',
#  'thats',
#  'little',
#  'desire',
#  'work',
#  'people',
#  'intolerance',
#  'allergy',
#  'food',
#  'complain',
#  'can',
#  'not',
#  'allow',
#  'need',
#  'desire',
#  'glove',
#  'clean',
#  'pan',
#  'customer',
#  'leave',
#  'happy',
#  'complicate',
#  'need',
#  'like',
#  'job',
#  'cheer',
#  'bad',
#  'service',
#  'disappointing',
#  'put',
#  'hot',
#  'water',
#  'us',
#  'complain',
#  'tell',
#  'us',
#  'cold',
#  'water',
#  'load',
#  'refrigerator',
#  '830',
#  'pm',
#  'night',
#  'seem',
#  'bad',
#  'management',
#  'cold',
#  'water',
#  'time',
#  'fair',
#  'attention',
#  'one',
#  'hamburger',
#  'completely',
#  'char',
#  'onion',
#  'high',
#  'price',
#  'quality',
#  'attention',
#  'el',
#  'movil',
#  'em',
#  'va',
#  'portar',
#  'aqui',
#  'sol',
#  'utilitzen',
#  'bot',
#  'per',
#  'atraure',
#  'gent',
#  'hi',
#  'anat',
#  'pero',
#  'tampoc',
#  'hi',
#  'aniré',
#  'brisket',
#  'serve',
#  'week',
#  'first',
#  'want',
#  'explain',
#  'give',
#  'one',
#  'star',
#  'two',
#  'year',
#  'ago',
#  'go',
#  'meat',
#  'melt',
#  'mouth',
#  'wonderful',
#  'quantity',
#  'large',
#  'ask',
#  'take',
#  'away',
#  'exquisite',
#  'flavor',
#  'fresh',
#  'two',
#  'year',
#  'ago',
#  'week',
#  'go',
#  'god',
#  'big',
#  'disappointment',
#  'tiny',
#  'amount',
#  'zero',
#  'taste',
#  'bad',
#  'soft',
#  'drink',
#  'ive',
#  'ever',
#  'life',
#  'mixture',
#  'water',
#  'sugar',
#  'turmeric',
#  'without',
#  'gas',
#  'supposedly',
#  'orange',
#  'one',
#  'rash',
#  'hand',
#  'leave',
#  'want',
#  'fair',
#  'say',
#  'attention',
#  'bad',
#  'make',
#  'sad',
#  'dont',
#  'think',
#  'come',
#  'back',
#  'would',
#  'nice',
#  'go',
#  'back',
#  'beginnings',
#  'dont',
#  'know',
#  'change',
#  'owner',
#  'decide',
#  'make',
#  'cut',
#  'everything',
#  'could',
#  'make',
#  'well',
#  'do',
#  'meat',
#  'first',
#  'time',
#  'make',
#  'wait',
#  '1',
#  'hour',
#  'food',
#  'friend',
#  'finish',
#  'eat',
#  'glass',
#  'pepsi',
#  'cost',
#  '35€',
#  'bad',
#  'service',
#  'high',
#  'price',
#  'good',
#  'food',
#  'bad',
#  'service',
#  'wrong',
#  'order',
#  'waiter',
#  'run',
#  'away',
#  'money',
#  'forgets',
#  'change',
#  'shame',
#  'delicious',
#  'food',
#  'dissapointed',
#  'place',
#  'cold',
#  'leave',
#  'jacket',
#  'seat',
#  'one',
#  'table',
#  'ask',
#  'move',
#  'stroller',
#  'saw',
#  'offer',
#  'us',
#  'first',
#  'table',
#  'let',
#  'tell',
#  'table',
#  'free',
#  'bother',
#  'anyone',
#  'super',
#  'weird',
#  'food',
#  'ok',
#  'bit',
#  'dry',
#  'side',
#  'far',
#  'texas',
#  'similar',
#  'pepsi',
#  'without',
#  'bubble',
#  'idea',
#  'never',
#  'write',
#  'bad',
#  'review',
#  'stick',
#  'bad',
#  'experience',
#  'serve',
#  'us',
#  'piece',
#  'burnt',
#  'meat',
#  'turn',
#  'deaf',
#  'ear',
#  'grievance',
#  'unprofessional',
#  'staff',
#  'start',
#  'bos',
#  'even',
#  'courage',
#  'ask',
#  'everything',
#  'go',
#  'well',
#  'avoid',
#  'carefully',
#  'ps',
#  'ask',
#  'medium',
#  'cooking',
#  'well',
#  'still',
#  'wait',
#  'serve',
#  'wasnt',
#  'crowd',
#  'slow',
#  'service',
#  'really',
#  'average',
#  'food',
#  'menu',
#  'wonderful',
#  'dish',
#  'attract',
#  'lot',
#  'attention',
#  'serve',
#  'food',
#  'terrible',
#  'food',
#  'american',
#  'flavor',
#  'anywhere',
#  'mislead',
#  'bbq',
#  'joint',
#  'it',
#  '’',
#  's',
#  'basically',
#  'steak',
#  'house',
#  'brisket',
#  'available',
#  'day',
#  'week',
#  'maybe',
#  'weekaccording',
#  'waiter',
#  'rude',
#  'initially',
#  'salad',
#  'come',
#  'sautéed',
#  'veggie',
#  'stir',
#  'fry',
#  'almost',
#  '1',
#  'star',
#  'give',
#  'beef',
#  'patty',
#  'burger',
#  'ok',
#  'misleading',
#  'edit',
#  'review',
#  'real',
#  'truthful',
#  'since',
#  'read',
#  'owner',
#  'respond',
#  'try',
#  'harsh',
#  'bad',
#  'behavior',
#  'staff',
#  'specially',
#  'arabs',
#  'customer',
#  'get',
#  'bad',
#  'racism',
#  'staff',
#  'arabs',
#  'recommend',
#  'visit',
#  'reason',
#  'deliberately',
#  'create',
#  'problem',
#  'arabs',
#  'customer',
#  'restaurant',
#  'worker',
#  'make',
#  'problem',
#  'arab',
#  'customer',
#  'rude',
#  'unfair',
#  'treatment',
#  'recommend',
#  'visit',
#  'restaurant',
#  'hope',
#  'staff',
#  'improve',
#  'behavior',
#  'drank',
#  'cook',
#  'without',
#  'mask',
#  'waiter',
#  'didnt',
#  'rinse',
#  'dish',
#  'also',
#  'wait',
#  'almost',
#  '1',
#  'hour',
#  'food',
#  'bring',
#  'us',
#  'didnt',
#  'eat',
#  'badly',
#  'dont',
#  'think',
#  'truth',
#  'come',
#  'back',
#  'oh',
#  'expensive',
#  'place',
#  'truth',
#  'lack',
#  'lot',
#  'education',
#  'attend',
#  'bad',
#  'attention',
#  'experience',
#  'fatal',
#  'bring',
#  'us',
#  'dish',
#  'others',
#  'miss',
#  'bring',
#  'us',
#  'extra',
#  'drink',
#  'ask',
#  'napkin',
#  'bring',
#  'us',
#  'throw',
#  'away',
#  'account',
#  'time',
#  'pay',
#  'ns',
#  'overcharge',
#  'thing',
#  'ask',
#  'glass',
#  'wine',
#  'want',
#  'charge',
#  'us',
#  'bottle',
#  'attention',
#  'fatal',
#  'part',
#  'group',
#  '10',
#  'people',
#  'return',
#  'scam',
#  'much',
#  'well',
#  'foster',
#  'hollywood',
#  'irony',
#  'cold',
#  'starter',
#  'regular',
#  'regular',
#  'meat',
#  'expensive',
#  'poor',
#  'quality',
#  'three',
#  'people',
#  'eat',
#  'three',
#  'find',
#  'burger',
#  'meat',
#  'compact',
#  'dry',
#  'didnt',
#  'look',
#  'like',
#  'black',
#  'angus',
#  'order',
#  'point',
#  'serve',
#  'us',
#  'well',
#  'do',
#  'quality',
#  'meat',
#  'appreciate',
#  'wait',
#  '1h',
#  'see',
#  'serve',
#  'people',
#  'enter',
#  'later',
#  'go',
#  'without',
#  'eat',
#  'best',
#  'tell',
#  'us',
#  'hope',
#  '10',
#  'minute',
#  'final',
#  'shot',
#  'consumption',
#  'charge',
#  'us',
#  '1h',
#  'nothing',
#  'recommendable',
#  'ive',
#  'go',
#  'long',
#  'time',
#  'already',
#  'twice',
#  'take',
#  'hour',
#  'serve',
#  'today',
#  'leave',
#  'without',
#  'eat',
#  'food',
#  'never',
#  'arrive',
#  'wont',
#  'back',
#  'slow',
#  'serving',
#  'hamburger',
#  'excessively',
#  'expensive',
#  'positive',
#  'point',
#  'highlight',
#  'nacho',
#  'unfortunately',
#  'burger',
#  'wasnt',
#  'hit',
#  'meat',
#  'wasnt',
#  'juicy',
#  'bad',
#  'food',
#  'couldnt',
#  'even',
#  'eat',
#  'anything',
#  'chip',
#  '🤢🤮',
#  'get',
#  'sick',
#  'eat',
#  'dinner',
#  '🤬',
#  '3',
#  'dry',
#  'half',
#  'ribs',
#  'two',
#  'slice',
#  'brisquet',
#  '90',
#  'gram',
#  'fat',
#  'two',
#  'portion',
#  'potato',
#  'frozen',
#  'cane',
#  '24',
#  'euro',
#  'leave',
#  'hungry',
#  'tourist',
#  'bet',
#  'pay',
#  'positive',
#  'recensions',
#  'impossible',
#  'site',
#  '4',
#  'star',
#  'order',
#  'california',
#  'burger',
#  'fry',
#  'fry',
#  'dry',
#  'even',
#  'mess',
#  'burger',
#  'make',
#  'low',
#  'quality',
#  'meat',
#  'texture',
#  'taste',
#  'bbq',
#  'sauce',
#  'super',
#  'market',
#  'quality',
#  'description',
#  'restaurant',
#  'say',
#  'make',
#  'soul',
#  'make',
#  'laugh',
#  'opinion',
#  'low',
#  'quality',
#  'food',
#  'tourist',
#  'marketing',
#  'concept',
#  'interior',
#  'design',
#  'make',
#  'professionally',
#  'pull',
#  'pork',
#  'rib',
#  'tomahawk',
#  'basically',
#  'main',
#  'dish',
#  'restaurant',
#  'like',
#  'need',
#  'supply',
#  'holiday',
#  'season',
#  'disappointed',
#  'see',
#  'advertising',
#  'instagram',
#  'good',
#  'review',
#  'around',
#  'clear',
#  'want',
#  'go',
#  'try',
#  'tomahawk',
#  'leave',
#  'sample',
#  'disappointment',
#  'whole',
#  'center',
#  'drier',
#  'eye',
#  'oneeyed',
#  'man',
#  'take',
#  'half',
#  'hour',
#  'serve',
#  'us',
#  'despite',
#  'fact',
#  'time',
#  'hardly',
#  'people',
#  'could',
#  'enjoy',
#  'food',
#  'either',
#  'two',
#  'photographer',
#  'take',
#  'granted',
#  'time',
#  'make',
#  'uncomfortable',
#  'second',
#  'time',
#  'wont',
#  'third',
#  'real',
#  'shame',
#  'like',
#  'give',
#  'heartburn',
#  'day',
#  'product',
#  'relieve',
#  'downgrade',
#  'review',
#  '1',
#  'star',
#  'due',
#  'terrible',
#  'response',
#  'owner',
#  'base',
#  'response',
#  'theyre',
#  'basically',
#  'say',
#  'minute',
#  'late',
#  'punish',
#  'terrible',
#  'service',
#  'table',
#  'cold',
#  'along',
#  'cold',
#  'food',
#  'forget',
#  'folk',
#  'get',
#  'good',
#  'dont',
#  'love',
#  'technology',
#  'please',
#  'see',
#  'timeline',
#  'image',
#  'attach',
#  'clearly',
#  'show',
#  'never',
#  'anywhere',
#  'near',
#  '25',
#  'minute',
#  'late',
#  'minute',
#  'log',
#  'time',
#  'hey',
#  'maybe',
#  'dont',
#  'leave',
#  'customer',
#  'wait',
#  'around',
#  'someone',
#  'eventually',
#  'seat',
#  'would',
#  'actually',
#  'time',
#  'oh',
#  'btw',
#  'maybe',
#  'go',
#  'speak',
#  'waiter',
#  'ask',
#  'nice',
#  'im',
#  '100',
#  'sure',
#  'waiter',
#  'disagree',
#  'never',
#  'blame',
#  'bad',
#  'experience',
#  'poor',
#  'guy',
#  'simply',
#  'overwhelm',
#  'due',
#  'bad',
#  'management',
#  'get',
#  'tip',
#  'us',
#  'regardless',
#  'clearly',
#  'enough',
#  'staff',
#  'amount',
#  'people',
#  'terrible',
#  'quality',
#  'control',
#  'serve',
#  'cold',
#  'food',
#  'clearly',
#  'can',
#  'not',
#  'accept',
#  'criticism',
#  'either',
#  'make',
#  'story',
#  '25',
#  '40',
#  'min',
#  'depend',
#  'word',
#  'minute',
#  'late',
#  'cheek',
#  'imply',
#  'nice',
#  'customer',
#  'leave',
#  'honest',
#  'feedback',
#  'oh',
#  'well',
#  'sangria',
#  'carafe',
#  'break',
#  'spilled',
#  'apology',
#  'staff',
#  'manager',
#  'blame',
#  'break',
#  'glass',
#  'burger',
#  'absolutely',
#  'awful',
#  'steak',
#  'gad',
#  'fat',
#  'meat',
#  'absolutely',
#  'bad',
#  'service',
#  'i',
#  '’',
#  've',
#  'ever',
#  'server',
#  'i',
#  '’',
#  've',
#  'never',
#  'situation',
#  'like',
#  'sangria',
#  'break',
#  'still',
#  'charge',
#  'us',
#  'sangria',
#  'absolutely',
#  'awful',
#  'please',
#  'don',
#  '’',
#  't',
#  'waste',
#  'time',
#  'money',
#  'food',
#  'overly',
#  'simple',
#  'overly',
#  'greasy',
#  'rude',
#  'staff',
#  'id',
#  'say',
#  'stay',
#  'away',
#  'go',
#  'somewhere',
#  'else',
#  'dry',
#  'hard',
#  'chew',
#  'fry',
#  'poor',
#  'quality',
#  'meat',
#  'burger',
#  'beer',
#  'alright',
#  'though',
#  'staff',
#  'friendly',
#  'bad',
#  'service',
#  'place',
#  'order',
#  'one',
#  'hour',
#  'ago',
#  'lose',
#  'dont',
#  'plan',
#  'provide',
#  'either',
#  ...]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [424], in <cell line: 3>()
#       1 pos = ['J','V','N','R']
# ----> 3 pos_filtered = [pos_tuple for pos_tuple in lemmatized_reviews if pos_tuple[1] in pos]
#       4 pos_filtered
#
# Input In [424], in <listcomp>(.0)
#       1 pos = ['J','V','N','R']
# ----> 3 pos_filtered = [pos_tuple for pos_tuple in lemmatized_reviews if pos_tuple[1] in pos]
#       4 pos_filtered
#
# IndexError: string index out of range

# %%
pos_lemm_words = [word[0] for word in pos_filtered]
pos_lemm_words
# Out:
# ['incredible',
#  'food',
#  'service',
#  'leaf',
#  'lot',
#  'food',
#  'everything',
#  'ive',
#  'twice',
#  'santa',
#  'fe',
#  'burnt',
#  'staff',
#  'attentive',
#  'customer',
#  'spanish',
#  'factor',
#  'linguistic',
#  'misunderstanding',
#  'food',
#  'garlic',
#  'difficulty',
#  'deaf',
#  'ear',
#  'full',
#  'oil',
#  'chock',
#  'full',
#  'garlic',
#  'second',
#  'time',
#  'first',
#  'garlic',
#  'santa',
#  'fe',
#  'medium',
#  'burnt',
#  'go',
#  'staff',
#  'request',
#  'excellent',
#  'quality',
#  'food',
#  'unable',
#  'cook',
#  'coke',
#  'gas',
#  'steak',
#  'chip',
#  'bad',
#  'quality',
#  'meat',
#  'fat',
#  'yesterday',
#  'first',
#  'food',
#  'intolerance',
#  'surprise',
#  'restaurant',
#  'name',
#  'many',
#  'visitor',
#  'nooo',
#  'food',
#  'seemed',
#  'easy',
#  'clean',
#  'little',
#  'desire',
#  'work',
#  'allergy',
#  'food',
#  'complain',
#  'cannot',
#  'need',
#  'desire',
#  'glove',
#  'clean',
#  'pan',
#  'customer',
#  'leaf',
#  'happy',
#  'like',
#  'job',
#  'cheer',
#  'bad',
#  'service',
#  'disappointing',
#  'hot',
#  'water',
#  'u',
#  'told',
#  'u',
#  'cold',
#  'water',
#  'refrigerator',
#  'pm',
#  'night',
#  'bad',
#  'management',
#  'cold',
#  'water',
#  'time',
#  'fair',
#  'attention',
#  'hamburger',
#  'onion',
#  'high',
#  'price',
#  'quality',
#  'attention',
#  'movil',
#  'em',
#  'va',
#  'portar',
#  'aqui',
#  'sol',
#  'utilitzen',
#  'bot',
#  'atraure',
#  'gent',
#  'hi',
#  'anat',
#  'pero',
#  'tampoc',
#  'hi',
#  'aniré',
#  'brisket',
#  'week',
#  'explain',
#  'give',
#  'star',
#  'year',
#  'meat',
#  'wonderful',
#  'quantity',
#  'large',
#  'exquisite',
#  'flavor',
#  'fresh',
#  'year',
#  'week',
#  'god',
#  'disappointment',
#  'tiny',
#  'amount',
#  'taste',
#  'soft',
#  'drink',
#  'ive',
#  'life',
#  'mixture',
#  'water',
#  'sugar',
#  'turmeric',
#  'gas',
#  'rash',
#  'hand',
#  'want',
#  'fair',
#  'attention',
#  'bad',
#  'sad',
#  'dont',
#  'nice',
#  'dont',
#  'change',
#  'owner',
#  'make',
#  'cut',
#  'everything',
#  'make',
#  'meat',
#  'first',
#  'time',
#  'hour',
#  'food',
#  'friend',
#  'glass',
#  'pepsi',
#  'cost',
#  'bad',
#  'service',
#  'high',
#  'price',
#  'good',
#  'food',
#  'bad',
#  'service',
#  'wrong',
#  'order',
#  'waiter',
#  'run',
#  'money',
#  'delicious',
#  'food',
#  'place',
#  'cold',
#  'jacket',
#  'table',
#  'stroller',
#  'saw',
#  'u',
#  'first',
#  'table',
#  'let',
#  'tell',
#  'table',
#  'free',
#  'anyone',
#  'super',
#  'weird',
#  'food',
#  'ok',
#  'bit',
#  'dry',
#  'side',
#  'texas',
#  'similar',
#  'pepsi',
#  'bubble',
#  'idea',
#  'bad',
#  'review',
#  'bad',
#  'experience',
#  'u',
#  'piece',
#  'burnt',
#  'meat',
#  'deaf',
#  'ear',
#  'grievance',
#  'unprofessional',
#  'staff',
#  'everything',
#  'p',
#  'medium',
#  'cooking',
#  'slow',
#  'service',
#  'average',
#  'food',
#  'menu',
#  'wonderful',
#  'dish',
#  'attract',
#  'lot',
#  'attention',
#  'food',
#  'terrible',
#  'food',
#  'american',
#  'flavor',
#  'bbq',
#  'joint',
#  'it’s',
#  'steak',
#  'house',
#  'brisket',
#  'available',
#  'day',
#  'week',
#  'salad',
#  'sautéed',
#  'veggie',
#  'stir',
#  'star',
#  'give',
#  'beef',
#  'ok',
#  'misleading',
#  'review',
#  'real',
#  'truthful',
#  'read',
#  'owner',
#  'harsh',
#  'bad',
#  'behavior',
#  'staff',
#  'arab',
#  'customer',
#  'get',
#  'bad',
#  'racism',
#  'staff',
#  'arab',
#  'recommend',
#  'reason',
#  'create',
#  'problem',
#  'arab',
#  'customer',
#  'restaurant',
#  'worker',
#  'problem',
#  'arab',
#  'customer',
#  'unfair',
#  'treatment',
#  'recommend',
#  'restaurant',
#  'hope',
#  'staff',
#  'improve',
#  'behavior',
#  'drank',
#  'cook',
#  'mask',
#  'waiter',
#  'didnt',
#  'rinse',
#  'dish',
#  'hour',
#  'food',
#  'u',
#  'didnt',
#  'eat',
#  'dont',
#  'truth',
#  'expensive',
#  'place',
#  'truth',
#  'lack',
#  'lot',
#  'education',
#  'bad',
#  'attention',
#  'experience',
#  'fatal',
#  'u',
#  'dish',
#  'u',
#  'extra',
#  'drink',
#  'napkin',
#  'u',
#  'account',
#  'time',
#  'n',
#  'thing',
#  'glass',
#  'wine',
#  'charge',
#  'u',
#  'bottle',
#  'attention',
#  'fatal',
#  'part',
#  'group',
#  'hollywood',
#  'irony',
#  'cold',
#  'starter',
#  'regular',
#  'regular',
#  'meat',
#  'expensive',
#  'poor',
#  'quality',
#  'meat',
#  'compact',
#  'dry',
#  'didnt',
#  'look',
#  'black',
#  'angus',
#  'point',
#  'quality',
#  'meat',
#  'see',
#  'serve',
#  'go',
#  'tell',
#  'hope',
#  'minute',
#  'final',
#  'shot',
#  'consumption',
#  'charge',
#  'u',
#  'nothing',
#  'recommendable',
#  'ive',
#  'long',
#  'time',
#  'take',
#  'hour',
#  'serve',
#  'today',
#  'food',
#  'wont',
#  'slow',
#  'serving',
#  'hamburger',
#  'expensive',
#  'positive',
#  'point',
#  'highlight',
#  'wasnt',
#  'hit',
#  'meat',
#  'wasnt',
#  'juicy',
#  'food',
#  'couldnt',
#  'anything',
#  'chip',
#  'get',
#  'sick',
#  'eat',
#  'dinner',
#  'dry',
#  'half',
#  'rib',
#  'slice',
#  'gram',
#  'fat',
#  'portion',
#  'potato',
#  'cane',
#  'euro',
#  'hungry',
#  'tourist',
#  'pay',
#  'positive',
#  'impossible',
#  'site',
#  'star',
#  'california',
#  'burger',
#  'fry',
#  'fry',
#  'dry',
#  'mess',
#  'burger',
#  'low',
#  'quality',
#  'meat',
#  'texture',
#  'taste',
#  'bbq',
#  'market',
#  'quality',
#  'description',
#  'restaurant',
#  'soul',
#  'opinion',
#  'low',
#  'quality',
#  'food',
#  'tourist',
#  'marketing',
#  'concept',
#  'interior',
#  'design',
#  'pull',
#  'pork',
#  'rib',
#  'tomahawk',
#  'main',
#  'dish',
#  'restaurant',
#  'need',
#  'supply',
#  'holiday',
#  'season',
#  'advertising',
#  'good',
#  'review',
#  'clear',
#  'go',
#  'try',
#  'sample',
#  'disappointment',
#  'whole',
#  'center',
#  'drier',
#  'eye',
#  'man',
#  'hour',
#  'u',
#  'fact',
#  'time',
#  'enjoy',
#  'food',
#  'photographer',
#  'granted',
#  'time',
#  'uncomfortable',
#  'second',
#  'time',
#  'wont',
#  'third',
#  'real',
#  'shame',
#  'day',
#  'product',
#  'relief',
#  'review',
#  'star',
#  'due',
#  'terrible',
#  'response',
#  'owner',
#  'response',
#  'theyre',
#  'minute',
#  'terrible',
#  'service',
#  'table',
#  'cold',
#  'cold',
#  'food',
#  'forget',
#  'folk',
#  'dont',
#  'technology',
#  'please',
#  'see',
#  'timeline',
#  'image',
#  'show',
#  'minute',
#  'late',
#  'minute',
#  'time',
#  'hey',
#  'dont',
#  'customer',
#  'someone',
#  'seat',
#  'time',
#  'oh',
#  'btw',
#  'speak',
#  'waiter',
#  'ask',
#  'nice',
#  'im',
#  'sure',
#  'waiter',
#  'disagree',
#  'bad',
#  'experience',
#  'poor',
#  'guy',
#  'due',
#  'bad',
#  'management',
#  'tip',
#  'u',
#  'enough',
#  'staff',
#  'amount',
#  'terrible',
#  'quality',
#  'control',
#  'food',
#  'cannot',
#  'criticism',
#  'story',
#  'min',
#  'minute',
#  'late',
#  'cheek',
#  'imply',
#  'nice',
#  'customer',
#  'feedback',
#  'sangria',
#  'spilled',
#  'apology',
#  'staff',
#  'manager',
#  'glass',
#  'burger',
#  'awful',
#  'steak',
#  'gad',
#  'fat',
#  'meat',
#  'worse',
#  'service',
#  'i’ve',
#  'i’ve',
#  'situation',
#  'u',
#  'awful',
#  'please',
#  'don’t',
#  'waste',
#  'time',
#  'money',
#  'food',
#  'simple',
#  'greasy',
#  'rude',
#  'staff',
#  'stay',
#  'go',
#  'dry',
#  'hard',
#  'chew',
#  'fry',
#  'poor',
#  'quality',
#  'meat',
#  'burger',
#  'beer',
#  'staff',
#  'bad',
#  'service',
#  'order',
#  'hour',
#  'dont',
#  'plan',
#  'talked',
#  'waiter',
#  'several',
#  'time',
#  'penous',
#  'service…',
#  'time',
#  'hour',
#  'dish',
#  'u',
#  'food',
#  'attached',
#  'photograph',
#  'thought',
#  'something',
#  'specific',
#  'something',
#  'usual',
#  'day',
#  'pm',
#  'hour',
#  'serve',
#  'u',
#  'attach',
#  'photo',
#  'time',
#  'run',
#  'restaurant',
#  'foreigner',
#  'food',
#  'worth',
#  'nothing',
#  'thank',
#  'hope',
#  'test',
#  'mistaken',
#  'local',
#  'rude',
#  'several',
#  'time',
#  'place',
#  'eats',
#  'chef',
#  'problem',
#  'meat',
#  'horrible',
#  'green',
#  'brisket',
#  'hope',
#  'get',
#  'p',
#  'give',
#  'sauce',
#  'boat',
#  'typical',
#  'kebab',
#  'terrible',
#  'huge',
#  'disappointment',
#  'place',
#  'late',
#  'lunch',
#  'rudeness',
#  'nefarious',
#  'service',
#  'authority',
#  'close',
#  'place',
#  'disastrous',
#  'u',
#  'hour',
#  'half',
#  'command',
#  'half',
#  'burger',
#  'inedible',
#  'bread',
#  'breaking',
#  'send',
#  'fry',
#  'dry',
#  'oily',
#  'addition',
#  'wrong',
#  'companion',
#  'service',
#  'friendly',
#  'waiter',
#  'friend',
#  'unprofessional',
#  'lot',
#  'space',
#  'le',
#  'much',
#  'hour',
#  'food',
#  'hamburger',
#  'dry',
#  'potato',
#  'terrible',
#  'service',
#  'waiter',
#  'busy',
#  'nothing',
#  'smoke',
#  'house',
#  'serf',
#  'non',
#  'beef',
#  'menu',
#  'response',
#  'comment',
#  'restaurant',
#  'prefer',
#  'say',
#  'ran',
#  'mention',
#  'anything',
#  'non',
#  'beef',
#  'false',
#  'advertising',
#  'poor',
#  'customer',
#  'service',
#  'slow',
#  'light',
#  'food',
#  'frozen',
#  'potato',
#  'expensive',
#  'website',
#  'letter',
#  'catalan',
#  'little',
#  'seriousness',
#  'respect',
#  'language',
#  'bad',
#  'it’s',
#  'place',
#  'bad',
#  'service',
#  'u',
#  'food',
#  'hour',
#  'half',
#  'late',
#  'table',
#  'reservation',
#  'take',
#  'long',
#  'time',
#  'take',
#  'notice',
#  'place',
#  'full',
#  'order',
#  'drink',
#  'food',
#  'nacho',
#  'starter',
#  'waiter',
#  'u',
#  'take',
#  'long',
#  'time',
#  'spam',
#  'true',
#  'dinner',
#  'tomahawk',
#  'thought',
#  'wait',
#  'worth',
#  'meat',
#  'sauce',
#  'happen',
#  'u',
#  'wait',
#  'time',
#  'poor',
#  'quality',
#  'slow',
#  'service',
#  'command',
#  'hour',
#  'several',
#  'call',
#  'attention',
#  'part',
#  'food',
#  'eaten',
#  'food',
#  'bad',
#  'side',
#  'bad',
#  'experience',
#  'im',
#  'crazy',
#  'high',
#  'expectation',
#  'review',
#  'comment',
#  'instagram',
#  'hype',
#  'pork',
#  'taste',
#  'anything',
#  'past',
#  'point',
#  'breast',
#  'starter',
#  'combo',
#  'mac',
#  'cheese',
#  'cube',
#  'cheese',
#  'tequeños',
#  'rib',
#  'pork',
#  'filling',
#  'much',
#  'good',
#  'rib',
#  'onion',
#  'ring',
#  'bad',
#  'potato',
#  'return',
#  'robbery',
#  'color',
#  'taste',
#  'werent',
#  'good',
#  'plenty',
#  'disappointed',
#  'small',
#  'rack',
#  'rib',
#  'nothing',
#  'dry',
#  'sausage',
#  'potato',
#  'powder',
#  'top',
#  'fu',
#  'fa',
#  'addition',
#  'confused',
#  'point',
#  'hamburger',
#  'dry',
#  'taste',
#  'anything',
#  'nothing',
#  'cheap',
#  'top',
#  'pepsi',
#  'premiere',
#  'place',
#  'arrive',
#  'partner',
#  'pm',
#  'terrace',
#  'come',
#  'attend',
#  'u',
#  'ten',
#  'minute',
#  'enter',
#  'order',
#  'menu',
#  'get',
#  'order',
#  'dinner',
#  'u',
#  'kitchen',
#  'minute',
#  'pm',
#  'u',
#  'incomplete',
#  'hamburger',
#  'ingredient',
#  'try',
#  'fill',
#  'lack',
#  'account',
#  'possible',
#  'allergen',
#  'deliver',
#  'u',
#  'time',
#  'waiter',
#  'regret',
#  'hamburger',
#  'incomplete',
#  'short',
#  'staff',
#  'stock',
#  'notify',
#  'minute',
#  'predisposition',
#  'accept',
#  'type',
#  'discount',
#  'disappointed',
#  'service',
#  'attention',
#  'good',
#  'rest',
#  'run',
#  'understand',
#  'barbecue',
#  'sauce',
#  'sweet',
#  'touch',
#  'sugar',
#  'sweet',
#  'cabbage',
#  'bean',
#  'shredded',
#  'meat',
#  'top',
#  'slice',
#  'bimbo',
#  'bread',
#  'rib',
#  'caramel',
#  'meat',
#  'tender',
#  'chicken',
#  'fall',
#  'point',
#  'distinguish',
#  'meat',
#  'injection',
#  'brine',
#  'turn',
#  'go',
#  'complete',
#  'disaster',
#  'food',
#  'critic',
#  'dedicate',
#  'something',
#  'nice',
#  'place',
#  'good',
#  'service',
#  'food',
#  'hand',
#  'expensive',
#  'average',
#  'hard',
#  'burger',
#  'bun',
#  'mac',
#  'cheese',
#  'starter',
#  'frozen',
#  'vegetable',
#  'basic',
#  'dessert',
#  'place',
#  'tourist',
#  'try',
#  'much',
#  'quality',
#  'quantity',
#  'attention',
#  'terrible',
#  'food',
#  'take',
#  'care',
#  'great',
#  'detail',
#  'area',
#  'good',
#  'restaurant',
#  'continue',
#  'competition',
#  'good',
#  ...]

# %%
pd.Series(pos_lemm_words).value_counts().head(10)
# Out:
# food          66
# bad           32
# meat          31
# u             29
# service       26
# time          25
# place         21
# good          20
# quality       19
# restaurant    18
# dtype: int64

# %%
rev_text['clean_text_merged'] = rev_text['clean_text'].apply(lambda x: ' '.join(x))

# %%
Text(pos_lemm_words).concordance('meat')
# Out:
# Displaying 25 of 31 matches:
# cook coke gas steak chip bad quality meat fat yesterday first food intolerance
#  brisket week explain give star year meat wonderful quantity large exquisite f
# hange owner make cut everything make meat first time hour food friend glass pe
#  review bad experience u piece burnt meat deaf ear grievance unprofessional st
# d irony cold starter regular regular meat expensive poor quality meat compact
#  regular meat expensive poor quality meat compact dry didnt look black angus p
# didnt look black angus point quality meat see serve go tell hope minute final
# e positive point highlight wasnt hit meat wasnt juicy food couldnt anything ch
#  fry fry dry mess burger low quality meat texture taste bbq market quality des
# ger glass burger awful steak gad fat meat worse service i’ve i’ve situation u
# ay go dry hard chew fry poor quality meat burger beer staff bad service order
# several time place eats chef problem meat horrible green brisket hope get p gi
# e dinner tomahawk thought wait worth meat sauce happen u wait time poor qualit
# ch sugar sweet cabbage bean shredded meat top slice bimbo bread rib caramel me
# at top slice bimbo bread rib caramel meat tender chicken fall point distinguis
# ender chicken fall point distinguish meat injection brine turn go complete dis
# llet pork nothing rib cold food cold meat worth fry barbecue sauce repeat cour
# truth total disappointment ask point meat confirm point difficult swallow unde
# un food austin extra bacon time rush meat bacon bit stale hour half food burge
# acon bit stale hour half food burger meat dry didnt u kind discount terrible a
# cessive industrial sauce little food meat juicy bad food bad service tread yes
#  dont work measure gentleman measure meat good condition weird taste smell smo
#  frozen empty potato regular service meat good bad doesnt taste smoke smoke ho
# aste quality size dish small portion meat oil onion ring much ice didnt ask wa
# hema food delicious expensive amount meat tourist excellent place u live barce

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(Text(pos_lemm_words))
sorted(finder.ngram_fd.items(), key=lambda t: (-t[1], t[0]))[:20]
# Out:
# [(('mac', 'cheese'), 9),
#  (('bad', 'service'), 6),
#  (('hour', 'half'), 5),
#  (('quality', 'meat'), 5),
#  (('frozen', 'potato'), 4),
#  (('high', 'expectation'), 4),
#  (('hour', 'food'), 4),
#  (('plastic', 'cutlery'), 4),
#  (('poor', 'quality'), 4),
#  (('arab', 'customer'), 3),
#  (('bad', 'experience'), 3),
#  (('dry', 'didnt'), 3),
#  (('food', 'bad'), 3),
#  (('food', 'good'), 3),
#  (('high', 'price'), 3),
#  (('long', 'time'), 3),
#  (('meat', 'good'), 3),
#  (('terrible', 'service'), 3),
#  (('addition', 'wrong'), 2),
#  (('bad', 'management'), 2)]

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder = TrigramCollocationFinder.from_words(Text(pos_lemm_words))
sorted(finder.ngram_fd.items(), key=lambda t: (-t[1], t[0]))[:10]
#finder.apply_freq_filter(2)
#finder.nbest(trigram_measures.pmi, 20)
# Out:
# [(('food', 'bad', 'service'), 2),
#  (('hour', 'half', 'food'), 2),
#  (('long', 'time', 'take'), 2),
#  (('poor', 'quality', 'meat'), 2),
#  (('problem', 'arab', 'customer'), 2),
#  (('take', 'long', 'time'), 2),
#  (('accept', 'type', 'discount'), 1),
#  (('accompany', 'culinary', 'offer'), 1),
#  (('account', 'possible', 'allergen'), 1),
#  (('account', 'time', 'n'), 1)]
